# %%
# !pip install -r requirements.txt
# !pip install html2text
# !pip install requests-html
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 2)) (4.11.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->-r requirements.txt (line 1)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->-r requirements.txt (line 1)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->-r requirements.txt (line 1)) (2023.11.17)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->-r requirements.txt (line 2)) (2.5)
# Requirement already satisfied: html2text in /usr/local/lib/python3.10/dist-packages (2020.1.16)
# Collecting requests-html
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from requests-html) (2.31.0)
# Collecting pyquery (from requests-html)
#   Downloading pyquery-2.0.0-py3-none-any.whl (22 kB)
# Collecting fake-useragent (from requests-html)
#   Downloading fake_useragent-1.4.0-py3-none-any.whl (15 kB)
# Collecting parse (from requests-html)
#   Downloading parse-1.20.0-py2.py3-none-any.whl (19 kB)
# Collecting bs4 (from requests-html)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Collecting w3lib (from requests-html)
#   Downloading w3lib-2.1.2-py3-none-any.whl (21 kB)
# Collecting pyppeteer>=0.0.14 (from requests-html)
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (1.4.4)
# Requirement already satisfied: certifi>=2021 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (2023.11.17)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (7.0.1)
# Collecting pyee<9.0.0,>=8.1.0 (from pyppeteer>=0.0.14->requests-html)
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (4.66.1)
# Collecting urllib3<2.0.0,>=1.25.8 (from pyppeteer>=0.0.14->requests-html)
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 5.8 MB/s eta 0:00:00
# Collecting websockets<11.0,>=10.0 (from pyppeteer>=0.0.14->requests-html)
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->requests-html) (4.11.2)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.10/dist-packages (from pyquery->requests-html) (4.9.4)
# Collecting cssselect>=1.2.0 (from pyquery->requests-html)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->requests-html) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->requests-html) (3.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html) (3.17.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->requests-html) (2.5)
# Installing collected packages: pyee, parse, fake-useragent, websockets, w3lib, urllib3, cssselect, pyquery, pyppeteer, bs4, requests-html
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
# Successfully installed bs4-0.0.2 cssselect-1.2.0 fake-useragent-1.4.0 parse-1.20.0 pyee-8.2.2 pyppeteer-1.0.2 pyquery-2.0.0 requests-html-0.10.0 urllib3-1.26.18 w3lib-2.1.2 websockets-10.4

# %%
import time

import requests

# %%
url = "https://visitseattle.org/events/page/1"

# Create -> POST
# Read   -> GET
# Update -> PUT
# Delete -> DELETE
#
# requests.post("https://concert.com/buy")
# requests.put("https://github.com/ianchen06")
# requests.delete("https://facebook.com/ianchen06/post/1")

res = requests.get(url)

# %%
# 200 -> OK
# 201 -> Created (after POST)
# 301 -> Moved Permanently
# 302
# 400 -> Bad Request (error from user)
# 404 -> Not Found (error from user)
# 500 -> Internal Server Error (error from server)
res.status_code
# Out:
# 200

# %%
res.text
# Out:
# '<!doctype html>\r\n<html lang="en-US">\r\n<head> <script type="text/javascript">\n/* <![CDATA[ */\n var gform;gform||(document.addEventListener("gform_main_scripts_loaded",function(){gform.scriptsLoaded=!0}),window.addEventListener("DOMContentLoaded",function(){gform.domLoaded=!0}),gform={domLoaded:!1,scriptsLoaded:!1,initializeOnLoaded:function(o){gform.domLoaded&&gform.scriptsLoaded?o():!gform.domLoaded&&gform.scriptsLoaded?window.addEventListener("DOMContentLoaded",o):document.addEventListener("gform_main_scripts_loaded",o)},hooks:{action:{},filter:{}},addAction:function(o,n,r,t){gform.addHook("action",o,n,r,t)},addFilter:function(o,n,r,t){gform.addHook("filter",o,n,r,t)},doAction:function(o){gform.doHook("action",o,arguments)},applyFilters:function(o){return gform.doHook("filter",o,arguments)},removeAction:function(o,n){gform.removeHook("action",o,n)},removeFilter:function(o,n,r){gform.removeHook("filter",o,n,r)},addHook:function(o,n,r,t,i){null==gform.hooks[o][n]&&(gform.hooks[o][n]=[]);var e=gform.hooks[o][n];null==i&&(i=n+"_"+e.length),gform.hooks[o][n].push({tag:i,callable:r,priority:t=null==t?10:t})},doHook:function(n,o,r){var t;if(r=Array.prototype.slice.call(r,1),null!=gform.hooks[n][o]&&((o=gform.hooks[n][o]).sort(function(o,n){return o.priority-n.priority}),o.forEach(function(o){"function"!=typeof(t=o.callable)&&(t=window[t]),"action"==n?t.apply(null,r):r[0]=t.apply(null,r)})),"filter"==n)return r[0]},removeHook:function(o,n,t,i){var r;null!=gform.hooks[o][n]&&(r=(r=gform.hooks[o][n]).filter(function(o,n,r){return!!(null!=i&&i!=o.tag||null!=t&&t!=o.priority)}),gform.hooks[o][n]=r)}}); \n/* ]]> */\n</script>\n\r\n    \r\n    <meta http-equiv="Content-Type"\r\n          content="text/html; charset=UTF-8"/>\r\n    <meta name="viewport" content="width=device-width, initial-scale=1">\r\n    <meta name="application-name" content="Visit Seattle"/>\r\n    <meta name="google-site-verification"\r\n          content="XMxLNYBJpveaQyQsj6qvtweLwfpyvUXwfe9wA186eLg"/>\r\n\r\n    \r\n    <!-- 1/04/2017 -->\r\n<link rel="apple-touch-icon" sizes="180x180" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon.png?v=pgq06ygd45">\r\n<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon-precomposed.png?v=pgq06ygd45">\r\n<link rel="apple-touch-icon-precomposed" sizes="57x57" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon-57x57.png" />\r\n<link rel="apple-touch-icon-precomposed" sizes="114x114" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon-114x114.png" />\r\n<link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon-72x72.png" />\r\n<link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon-144x144.png" />\r\n<link rel="apple-touch-icon-precomposed" sizes="60x60" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon-60x60.png" />\r\n<link rel="apple-touch-icon-precomposed" sizes="120x120" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon-120x120.png" />\r\n<link rel="apple-touch-icon-precomposed" sizes="76x76" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon-76x76.png" />\r\n<link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon-152x152.png" />\r\n<link rel="icon" type="image/png" sizes="32x32" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/favicon-32x32.png?v=pgq06ygd45">\r\n<link rel="icon" ty ...

# %%
open("seattleevents.html", "w").write(res.text)
# Out:
# 182482

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(res.text, "html.parser")

# %%
selector = "div.search-result-preview > div > h3 > a"

a_eles = soup.select(selector)
a_eles
# Out:
# [<a href="https://visitseattle.org/events/kate-alice-marshall/" title="Kate Alice Marshall">Kate Alice Marshall </a>,
#  <a href="https://visitseattle.org/events/machine-head/" title="Machine Head">Machine Head </a>,
#  <a href="https://visitseattle.org/events/silent-movie-mondays-safety-last/" title="Silent Movie Mondays – Safety Last">Silent Movie Mondays – Safety Last </a>,
#  <a href="https://visitseattle.org/events/life-on-thin-ice-national-geographic-live/" title="Life on Thin Ice | National Geographic Live">Life on Thin Ice | National Geographic Live </a>,
#  <a href="https://visitseattle.org/events/buck-meek/" title="Buck Meek">Buck Meek </a>,
#  <a href="https://visitseattle.org/events/curator-tour-joseph-a-witt-winter-garden/" title="Curator Tour: Joseph A. Witt Winter Garden">Curator Tour: Joseph A. Witt Winter Garden </a>,
#  <a href="https://visitseattle.org/events/synthwave-dj-dance-party/" title="Synthwave DJ Dance Party">Synthwave DJ Dance Party </a>,
#  <a href="https://visitseattle.org/events/wiley-from-atlanta/" title="Wiley from Atlanta">Wiley from Atlanta </a>,
#  <a href="https://visitseattle.org/events/winter-reverb/" title="Winter Reverb">Winter Reverb </a>]

# %%
[x['href'] for x in a_eles]
# Out:
# ['https://visitseattle.org/events/kate-alice-marshall/',
#  'https://visitseattle.org/events/machine-head/',
#  'https://visitseattle.org/events/silent-movie-mondays-safety-last/',
#  'https://visitseattle.org/events/life-on-thin-ice-national-geographic-live/',
#  'https://visitseattle.org/events/buck-meek/',
#  'https://visitseattle.org/events/curator-tour-joseph-a-witt-winter-garden/',
#  'https://visitseattle.org/events/synthwave-dj-dance-party/',
#  'https://visitseattle.org/events/wiley-from-atlanta/',
#  'https://visitseattle.org/events/winter-reverb/']

# %%
import requests
from bs4 import BeautifulSoup

for url in ['https://visitseattle.org/events/kate-alice-marshall/', 'https://visitseattle.org/events/machine-head/', ...]:
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an HTTPError for bad responses
        soup = BeautifulSoup(response.text, 'html.parser')
        # Extract information from the HTML using BeautifulSoup
        # Example: print the title of the page
        title = soup.title.string.strip()
        print(f"Title of {url}: {title}")
    except requests.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
# Out:
# Title of https://visitseattle.org/events/kate-alice-marshall/: Kate Alice Marshall | Visit Seattle
# Title of https://visitseattle.org/events/machine-head/: Machine Head | Visit Seattle
# Error fetching data from Ellipsis: Invalid URL 'Ellipsis': No scheme supplied. Perhaps you meant https://Ellipsis?

# %%
import requests
from bs4 import BeautifulSoup

def scrape_event_urls(url):
    event_urls = []

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an HTTPError for bad responses
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract event URLs using the provided CSS selector
        selector = "div.search-result-preview > div > h3 > a"
        event_tags = soup.select(selector)
        event_urls.extend([tag['href'] for tag in event_tags])

        return event_urls
    except requests.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return None

# Scraping event URLs from all pages
base_url = "https://visitseattle.org/events/page/"
total_pages = 41  # You mentioned 41 pages
all_event_urls = []

for page_number in range(1, total_pages + 1):
    url = f"{base_url}{page_number}"
    event_urls = scrape_event_urls(url)

    if event_urls:
        all_event_urls.extend(event_urls)

# Print the result
print(all_event_urls)
# Out:
# ['https://visitseattle.org/events/steinunn-porarinsdottir-wayfinders/', 'https://visitseattle.org/events/hanako-oleary-izanami/', 'https://visitseattle.org/events/gage-alumni-show/', 'https://visitseattle.org/events/genre-box/', 'https://visitseattle.org/events/bohemia/', 'https://visitseattle.org/events/alice-in-shadowland/', 'https://visitseattle.org/events/lee-ritenour-and-dave-grusin/', 'https://visitseattle.org/events/tacoma-home-garden-show/', 'https://visitseattle.org/events/annie-eastwood-with-kimball-and-the-fugitives/', 'https://visitseattle.org/events/black-and-boujee-panel-discussion/', 'https://visitseattle.org/events/celebrate-asia/', 'https://visitseattle.org/events/djangos-birthday-concert-with-ranger-and-the-re-arrangers/', 'https://visitseattle.org/events/family-day-with-birds-connect-seattle/', 'https://visitseattle.org/events/fossil-finders-ice-ages/', 'https://visitseattle.org/events/seattle-kraken-vs-columbus-blue-jackets/', 'https://visitseattle.org/events/tacoma-stars-vs-san-diego-sockers-3/', 'https://visitseattle.org/events/adira-sharkey/', 'https://visitseattle.org/events/car-the-garden/', 'https://visitseattle.org/events/walla-walla-wine-on-tour/', 'https://visitseattle.org/events/cheryl-wheeler/', 'https://visitseattle.org/events/giantish/', 'https://visitseattle.org/events/seattle-thunderbirds-vs-prince-george-cougars-2/', 'https://visitseattle.org/events/a-political-rocks/', 'https://visitseattle.org/events/sophia-al-maria/', 'https://visitseattle.org/events/jahari-stampley/', 'https://visitseattle.org/events/fraktured-home-of-the-broken-beat/', 'https://visitseattle.org/events/g3-25th-anniversary-reunion/', 'https://visitseattle.org/events/jp-saxe/', 'https://visitseattle.org/events/los-lobos/', 'https://visitseattle.org/events/the-daimonics/', 'https://visitseattle.org/events/babytron/', 'https://visitseattle.org/events/battlestar-kalakala/', 'https://visitseattle.org/events/catalyzing-change-with-akuyea-karen-vargas/', 'https://visitseattle.org/events/exceptional-failures/', 'https://visitseattle.org/events/jamila-woods/', 'https://visitseattle.org/events/jazz-is-dead-blue-note-85/', 'https://visitseattle.org/events/michelle-cann/', 'https://visitseattle.org/events/pakt/', 'https://visitseattle.org/events/public-theatre/', 'https://visitseattle.org/events/american-flats-album-release/', 'https://visitseattle.org/events/erik-walters/', 'https://visitseattle.org/events/memoir/', 'https://visitseattle.org/events/nora-en-pure/', 'https://visitseattle.org/events/poolside/', 'https://visitseattle.org/events/tacoma-stars-vs-monterrey-flash/', 'https://visitseattle.org/events/jaha-koo-the-history-of-korean-western-theatre/', 'https://visitseattle.org/events/the-winds-medley-of-emotions/', 'https://visitseattle.org/events/all-will-suffer/', 'https://visitseattle.org/events/banned-beloved/', 'https://visitseattle.org/events/cold-war-kids-20-years-tour/', 'https://visitseattle.org/events/mau-p/', 'https://visitseattle.org/events/oble/', 'https://visitseattle.org/events/randy-rainbow-for-president/', 'https://visitseattle.org/events/the-delta-bombers/', 'https://visitseattle.org/events/the-grave-plot-film-fest-part-6/', 'https://visitseattle.org/events/seattle-chamber-music-winter-festival/', 'https://visitseattle.org/events/beethoven-emperor-concerto/', 'https://visitseattle.org/events/sergio-mendes/', 'https://visitseattle.org/events/daniel-tigers-neighborhood/', 'https://visitseattle.org/events/family-art-day-la-vaughn-belle/', 'https://visitseattle.org/events/lil-skies/', 'https://visitseattle.org/events/secular-and-sacred/', 'https://visitseattle.org/events/criminal/', 'https://visitseattle.org/events/neck-deep/', 'https://visitseattle.org/events/kazu-kibuishi-with-donna-barba-higuera/', 'https://visitseattle.org/events/kristin-hannah/', 'https://visitseattle.org/events/michael-j-gerhardt/', 'https://visitseattle.org/events/night-lovell/', 'https://visitseattle.org/events/soja/', 'https://visitseattl ...

# %%
import requests
from bs4 import BeautifulSoup
import csv

def extract_event_details(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an HTTPError for bad responses
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract information from the HTML using BeautifulSoup
        name = soup.find('h1', class_='page-title').text.strip()
        date = soup.find("h4").find_all("span")[0].text.strip()
        location = soup.find("h4").find_all("span")[1].text.strip()
        event_type = soup.find_all("a", class_="button big medium black category")[0].text.strip()
        region = soup.find_all("a", class_="button big medium black category")[1].text.strip()

        # Store the details in a dictionary
        event_details = {
            'Name': name,
            'Date': date,
            'Location': location,
            'Type': event_type,
            'Region': region
        }

        print(f"Details for {name} ({url}):")
        print(f"  Date: {date}")
        print(f"  Location: {location}")
        print(f"  Type: {event_type}")
        print(f"  Region: {region}")
        print()

        return event_details

    except requests.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return None

# List of event URLs


all_event_details = []

# Extract details for each event URL
for url in all_event_urls:
    event_details = extract_event_details(url)
    if event_details:
        all_event_details.append(event_details)

# Store the details in a CSV file
csv_file_path = 'events.csv'
fields = ['Name', 'Date', 'Location', 'Type', 'Region']

with open(csv_file_path, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fields)
    # Write the header
    writer.writeheader()
    # Write the event details
    writer.writerows(all_event_details)

print(f"Event details stored in {csv_file_path}")
# Out:
# Details for Steinunn Porarinsdottir: Wayfinders (https://visitseattle.org/events/steinunn-porarinsdottir-wayfinders/):
#   Date: Now through 1/28/2024
#   Location: National Nordic Museum
#   Type: Museums
#   Region: Fremont / Ballard
#
# Details for Hanako O’Leary: Izanami (https://visitseattle.org/events/hanako-oleary-izanami/):
#   Date: Now through 1/28/2024
#   Location: Frye Art Museum
#   Type: Museums
#   Region: Capitol Hill / Central District
#
# Details for Gage Alumni Show (https://visitseattle.org/events/gage-alumni-show/):
#   Date: Now through 1/28/2024
#   Location: Fountainhead Gallery
#   Type: Visual Arts & Galleries
#   Region: Queen Anne / Seattle Center
#
# Details for Genre Box (https://visitseattle.org/events/genre-box/):
#   Date: Now through 1/28/2024
#   Location: Market Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for Bohemia (https://visitseattle.org/events/bohemia/):
#   Date: Now through 1/28/2024
#   Location: The Triple Door
#   Type: Theatre
#   Region: Downtown
#
# Details for Alice in Shadowland (https://visitseattle.org/events/alice-in-shadowland/):
#   Date: Now through 1/28/2024
#   Location: 12th Avenue Arts
#   Type: Theatre
#   Region: Capitol Hill / Central District
#
# Details for Lee Ritenour and Dave Grusin (https://visitseattle.org/events/lee-ritenour-and-dave-grusin/):
#   Date: Now through 1/28/2024
#   Location: Dimitriou's Jazz Alley
#   Type: Music
#   Region: Downtown
#
# Details for Tacoma Home + Garden Show (https://visitseattle.org/events/tacoma-home-garden-show/):
#   Date: Now through 1/28/2024
#   Location: Tacoma Dome
#   Type: Festivals & Special Events
#   Region: South
#
# Details for Annie Eastwood with Kimball and the Fugitives (https://visitseattle.org/events/annie-eastwood-with-kimball-and-the-fugitives/):
#   Date: 1/28/2024
#   Location: Sea Monster Lounge
#   Type: Music
#   Region: Wallingford / Greenlake
#
# Details for Black and Boujee Panel Discussion (https://visitseattle.org/events/black-and-boujee-panel-discussion/):
#   Date: 1/28/2024
#   Location: Bainbridge Island Museum of Art
#   Type: Readings & Lectures
#   Region: West
#
# Details for Celebrate Asia (https://visitseattle.org/events/celebrate-asia/):
#   Date: 1/28/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Django’s Birthday Concert with Ranger and the Re-Arrangers (https://visitseattle.org/events/djangos-birthday-concert-with-ranger-and-the-re-arrangers/):
#   Date: 1/28/2024
#   Location: The Royal Room
#   Type: Music
#   Region: South Seattle
#
# Details for Family Day with Birds Connect Seattle (https://visitseattle.org/events/family-day-with-birds-connect-seattle/):
#   Date: 1/28/2024
#   Location: National Nordic Museum
#   Type: Museums
#   Region: Fremont / Ballard
#
# Details for Fossil Finders | Ice Ages (https://visitseattle.org/events/fossil-finders-ice-ages/):
#   Date: 1/28/2024
#   Location: Burke Museum
#   Type: Museums
#   Region: University District
#
# Details for Seattle Kraken vs. Columbus Blue Jackets (https://visitseattle.org/events/seattle-kraken-vs-columbus-blue-jackets/):
#   Date: 1/28/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Tacoma Stars vs. San Diego Sockers (https://visitseattle.org/events/tacoma-stars-vs-san-diego-sockers-3/):
#   Date: 1/28/2024
#   Location: accesso ShoWare Center
#   Type: Sports
#   Region: South
#
# Details for Adira Sharkey (https://visitseattle.org/events/adira-sharkey/):
#   Date: 1/29/2024
#   Location: Tractor Tavern
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Car, The Garden (https://visitseattle.org/events/car-the-garden/):
#   Date: 1/29/2024
#   Location: The Crocodile
#   Type: Music
#   Region: Downtown
#
# Details for Walla Walla Wine On Tour (https://visitseattle.org/events/walla-walla-wine-on-tour/):
#   Date: 1/29/2024
#   Location: Marion Oliver McCaw Hall
#   Type: Festivals & Special Events
#   Region: Queen Anne / Seattle Center
#
# Details for Cheryl Wheeler (https://visitseattle.org/events/cheryl-wheeler/):
#   Date: 1/30/2024
#   Location: The Triple Door
#   Type: Music
#   Region: Downtown
#
# Details for Giantish (https://visitseattle.org/events/giantish/):
#   Date: 1/30/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Seattle Thunderbirds vs. Prince George Cougars (https://visitseattle.org/events/seattle-thunderbirds-vs-prince-george-cougars-2/):
#   Date: 1/30/2024
#   Location: accesso ShoWare Center
#   Type: Sports
#   Region: South
#
# Details for A/political Rocks (https://visitseattle.org/events/a-political-rocks/):
#   Date: Now through 1/31/2024
#   Location: Henry Art Gallery
#   Type: Museums
#   Region: University District
#
# Details for Sophia Al-Maria (https://visitseattle.org/events/sophia-al-maria/):
#   Date: Now through 1/31/2024
#   Location: Henry Art Gallery
#   Type: Museums
#   Region: University District
#
# Details for Jahari Stampley (https://visitseattle.org/events/jahari-stampley/):
#   Date: 1/30/2024 through 1/31/2024
#   Location: Dimitriou's Jazz Alley
#   Type: Music
#   Region: Downtown
#
# Details for FRAKTURED: Home of the Broken Beat (https://visitseattle.org/events/fraktured-home-of-the-broken-beat/):
#   Date: 1/31/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for G3- 25th Anniversary reunion (https://visitseattle.org/events/g3-25th-anniversary-reunion/):
#   Date: 1/31/2024
#   Location: The Moore Theatre
#   Type: Music
#   Region: Downtown
#
# Details for JP Saxe (https://visitseattle.org/events/jp-saxe/):
#   Date: 1/31/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Los Lobos (https://visitseattle.org/events/los-lobos/):
#   Date: 1/31/2024
#   Location: The Triple Door
#   Type: Music
#   Region: Downtown
#
# Details for The Daimonics (https://visitseattle.org/events/the-daimonics/):
#   Date: 1/31/2024
#   Location: The Royal Room
#   Type: Music
#   Region: South Seattle
#
# Details for BabyTron (https://visitseattle.org/events/babytron/):
#   Date: 2/1/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Battlestar Kalakala (https://visitseattle.org/events/battlestar-kalakala/):
#   Date: 2/1/2024
#   Location: Sea Monster Lounge
#   Type: Music
#   Region: Wallingford / Greenlake
#
# Details for Catalyzing Change with Akuyea Karen Vargas (https://visitseattle.org/events/catalyzing-change-with-akuyea-karen-vargas/):
#   Date: 2/1/2024
#   Location: Bainbridge Island Museum of Art
#   Type: Readings & Lectures
#   Region: West
#
# Details for Exceptional Failures (https://visitseattle.org/events/exceptional-failures/):
#   Date: 2/1/2024
#   Location: Tractor Tavern
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Jamila Woods (https://visitseattle.org/events/jamila-woods/):
#   Date: 2/1/2024
#   Location: Neumos
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Jazz is Dead: Blue Note 85 (https://visitseattle.org/events/jazz-is-dead-blue-note-85/):
#   Date: 2/1/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for Michelle Cann (https://visitseattle.org/events/michelle-cann/):
#   Date: 2/1/2024
#   Location: Meany Center for the Performing Arts
#   Type: Music
#   Region: University District
#
# Details for Pakt (https://visitseattle.org/events/pakt/):
#   Date: 2/1/2024
#   Location: Funhouse
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Public Theatre (https://visitseattle.org/events/public-theatre/):
#   Date: 2/1/2024
#   Location: Barboza
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for American Flats Album Release (https://visitseattle.org/events/american-flats-album-release/):
#   Date: 2/2/2024
#   Location: The Royal Room
#   Type: Music
#   Region: South Seattle
#
# Details for Erik Walters (https://visitseattle.org/events/erik-walters/):
#   Date: 2/2/2024
#   Location: Barboza
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Memoir (https://visitseattle.org/events/memoir/):
#   Date: 2/2/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Nora En Pure (https://visitseattle.org/events/nora-en-pure/):
#   Date: 2/2/2024
#   Location: Showbox SoDo
#   Type: Music
#   Region: Pioneer Square
#
# Details for Poolside (https://visitseattle.org/events/poolside/):
#   Date: 2/2/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Tacoma Stars vs. Monterrey Flash (https://visitseattle.org/events/tacoma-stars-vs-monterrey-flash/):
#   Date: 2/2/2024
#   Location: accesso ShoWare Center
#   Type: Sports
#   Region: South
#
# Details for Jaha Koo: The History of Korean Western Theatre (https://visitseattle.org/events/jaha-koo-the-history-of-korean-western-theatre/):
#   Date: 2/1/2024 through 2/3/2024
#   Location: On The Boards
#   Type: Theatre
#   Region: Queen Anne / Seattle Center
#
# Details for The Winds: Medley of Emotions (https://visitseattle.org/events/the-winds-medley-of-emotions/):
#   Date: 2/2/2024 through 2/3/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for All Will Suffer (https://visitseattle.org/events/all-will-suffer/):
#   Date: 2/3/2024
#   Location: Funhouse
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Banned & Beloved (https://visitseattle.org/events/banned-beloved/):
#   Date: 2/3/2024
#   Location: Town Hall Seattle
#   Type: Music
#   Region: Downtown
#
# Details for Cold War Kids – 20 Years Tour (https://visitseattle.org/events/cold-war-kids-20-years-tour/):
#   Date: 2/3/2024
#   Location: The Moore Theatre
#   Type: Music
#   Region: Downtown
#
# Details for Mau P (https://visitseattle.org/events/mau-p/):
#   Date: 2/3/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Oble (https://visitseattle.org/events/oble/):
#   Date: 2/3/2024
#   Location: Barboza
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Randy Rainbow for President (https://visitseattle.org/events/randy-rainbow-for-president/):
#   Date: 2/3/2024
#   Location: The Paramount Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for The Delta Bombers (https://visitseattle.org/events/the-delta-bombers/):
#   Date: 2/3/2024
#   Location: El Corazon
#   Type: Music
#   Region: Downtown
#
# Details for The Grave Plot Film Fest part 6 (https://visitseattle.org/events/the-grave-plot-film-fest-part-6/):
#   Date: 2/3/2024
#   Location: Ark Lodge Cinemas
#   Type: Film & Media Arts
#   Region: South Seattle
#
# Details for Seattle Chamber Music Winter Festival (https://visitseattle.org/events/seattle-chamber-music-winter-festival/):
#   Date: Now through 2/4/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Beethoven Emperor Concerto (https://visitseattle.org/events/beethoven-emperor-concerto/):
#   Date: 2/1/2024 through 2/4/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Sergio Mendes (https://visitseattle.org/events/sergio-mendes/):
#   Date: 2/1/2024 through 2/4/2024
#   Location: Dimitriou's Jazz Alley
#   Type: Music
#   Region: Downtown
#
# Details for Daniel Tiger’s Neighborhood (https://visitseattle.org/events/daniel-tigers-neighborhood/):
#   Date: 2/4/2024
#   Location: The Paramount Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for Family Art Day: La Vaughn Belle (https://visitseattle.org/events/family-art-day-la-vaughn-belle/):
#   Date: 2/4/2024
#   Location: National Nordic Museum
#   Type: Museums
#   Region: Fremont / Ballard
#
# Details for Lil Skies (https://visitseattle.org/events/lil-skies/):
#   Date: 2/4/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Secular and Sacred (https://visitseattle.org/events/secular-and-sacred/):
#   Date: 2/4/2024
#   Location: Town Hall Seattle
#   Type: Music
#   Region: Downtown
#
# Details for Criminal (https://visitseattle.org/events/criminal/):
#   Date: 2/5/2024
#   Location: The Moore Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for Neck Deep (https://visitseattle.org/events/neck-deep/):
#   Date: 2/5/2024
#   Location: Showbox SoDo
#   Type: Music
#   Region: Pioneer Square
#
# Details for Kazu Kibuishi with Donna Barba Higuera (https://visitseattle.org/events/kazu-kibuishi-with-donna-barba-higuera/):
#   Date: 2/6/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Kristin Hannah (https://visitseattle.org/events/kristin-hannah/):
#   Date: 2/6/2024
#   Location: Benaroya Hall
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Michael J. Gerhardt (https://visitseattle.org/events/michael-j-gerhardt/):
#   Date: 2/6/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Night Lovell (https://visitseattle.org/events/night-lovell/):
#   Date: 2/6/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Soja (https://visitseattle.org/events/soja/):
#   Date: 2/6/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for Kenny Barron Trio (https://visitseattle.org/events/kenny-barron-trio/):
#   Date: 2/6/2024 through 2/7/2024
#   Location: Dimitriou's Jazz Alley
#   Type: Music
#   Region: Downtown
#
# Details for Dimiter (https://visitseattle.org/events/dimiter/):
#   Date: 2/7/2024
#   Location: Sunset Tavern
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Tamara Payne: The Life and Legacy of Malcolm X (https://visitseattle.org/events/tamara-payne-the-life-and-legacy-of-malcolm-x/):
#   Date: 2/7/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for The Kills (https://visitseattle.org/events/the-kills/):
#   Date: 2/7/2024
#   Location: Showbox SoDo
#   Type: Music
#   Region: Pioneer Square
#
# Details for An Evening with Tina Campt: Black Feminist Visual Culture (https://visitseattle.org/events/an-evening-with-tina-campt-black-feminist-visual-culture/):
#   Date: 2/8/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Art and Transformation (https://visitseattle.org/events/art-and-transformation/):
#   Date: 2/8/2024
#   Location: Bainbridge Island Museum of Art
#   Type: Readings & Lectures
#   Region: West
#
# Details for Eric Bellinger (https://visitseattle.org/events/eric-bellinger/):
#   Date: 2/8/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Futurebirds and Nude Party (https://visitseattle.org/events/futurebirds-and-nude-party/):
#   Date: 2/8/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for Ilana Glazer Live (https://visitseattle.org/events/ilana-glazer-live/):
#   Date: 2/8/2024
#   Location: The Moore Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for Mister Blank (https://visitseattle.org/events/mister-blank/):
#   Date: 2/8/2024
#   Location: Nectar Lounge
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for The Thorn (https://visitseattle.org/events/the-thorn/):
#   Date: 2/8/2024 through 2/9/2024
#   Location: The Paramount Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for Barry Can’t Swim (https://visitseattle.org/events/barry-cant-swim/):
#   Date: 2/9/2024
#   Location: Neumos
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Dark Star Orchestra (https://visitseattle.org/events/dark-star-orchestra/):
#   Date: 2/9/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Gov’t Mule (https://visitseattle.org/events/govt-mule/):
#   Date: 2/9/2024
#   Location: The Moore Theatre
#   Type: Music
#   Region: Downtown
#
# Details for Ijeoma Oluo: Be A Revolution (https://visitseattle.org/events/ijeoma-oluo-be-a-revolution/):
#   Date: 2/9/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Mayer Hawthorne (https://visitseattle.org/events/mayer-hawthorne/):
#   Date: 2/9/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for Moontricks (https://visitseattle.org/events/moontricks/):
#   Date: 2/9/2024
#   Location: The Crocodile
#   Type: Music
#   Region: Downtown
#
# Details for OBOE / OBOE (https://visitseattle.org/events/oboe-oboe/):
#   Date: 2/9/2024
#   Location: 415 Westlake
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Roots and Wings (https://visitseattle.org/events/roots-and-wings/):
#   Date: 2/9/2024
#   Location: Rendezvous JewelBox Theater
#   Type: Theatre
#   Region: Downtown
#
# Details for Seattle Boat Show (https://visitseattle.org/events/seattle-boat-show/):
#   Date: 2/2/2024 through 2/10/2024
#   Location: Lumen Field
#   Type: Festivals & Special Events
#   Region: Pioneer Square
#
# Details for Randall Goosby Plays Mozart (https://visitseattle.org/events/randall-goosby-plays-mozart/):
#   Date: 2/8/2024 through 2/10/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Art by Design (https://visitseattle.org/events/art-by-design/):
#   Date: 2/9/2024 through 2/10/2024
#   Location: Seattle Design Center
#   Type: Visual Arts & Galleries
#   Region: Downtown
#
# Details for The Love Show (https://visitseattle.org/events/the-love-show/):
#   Date: 2/9/2024 through 2/10/2024
#   Location: The Royal Room
#   Type: Theatre
#   Region: South Seattle
#
# Details for Brazilian Carnaval 2024 (https://visitseattle.org/events/brazilian-carnaval-2024/):
#   Date: 2/10/2024
#   Location: The Crocodile
#   Type: Music
#   Region: Downtown
#
# Details for Chase Rice (https://visitseattle.org/events/chase-rice/):
#   Date: 2/10/2024
#   Location: Showbox SoDo
#   Type: Music
#   Region: Pioneer Square
#
# Details for Joe “Mr. D”  Dombrowski (https://visitseattle.org/events/joe-mr-d-dombrowski/):
#   Date: 2/10/2024
#   Location: The Moore Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for JVNA (https://visitseattle.org/events/jvna/):
#   Date: 2/10/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Linda From Work (https://visitseattle.org/events/linda-from-work/):
#   Date: 2/10/2024
#   Location: Barboza
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for The Brother Brothers (https://visitseattle.org/events/the-brother-brothers/):
#   Date: 2/10/2024
#   Location: Tractor Tavern
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for The Temptations &  The Four Tops (https://visitseattle.org/events/the-temptations-the-four-tops/):
#   Date: 2/10/2024
#   Location: The Paramount Theatre
#   Type: Music
#   Region: Downtown
#
# Details for Quixote Nuevo (https://visitseattle.org/events/quixote-nuevo/):
#   Date: Now through 2/11/2024
#   Location: Seattle Rep
#   Type: Theatre
#   Region: Queen Anne / Seattle Center
#
# Details for Kent Stowell’s Swan Lake (https://visitseattle.org/events/kent-stowells-swan-lake/):
#   Date: 2/2/2024 through 2/11/2024
#   Location: Marion Oliver McCaw Hall
#   Type: Dance
#   Region: Queen Anne / Seattle Center
#
# Details for Blood Sweat  and Tears (https://visitseattle.org/events/blood-sweat-and-tears/):
#   Date: 2/8/2024 through 2/11/2024
#   Location: Dimitriou's Jazz Alley
#   Type: Music
#   Region: Downtown
#
# Details for Love at the Zoo (https://visitseattle.org/events/love-at-the-zoo/):
#   Date: 2/10/2024 through 2/11/2024
#   Location: Point Defiance Zoo and Aquarium
#   Type: Festivals & Special Events
#   Region: South
#
# Details for Scott Bradlee’s Postmodern Jukebox (https://visitseattle.org/events/scott-bradlees-postmodern-jukebox/):
#   Date: 2/11/2024
#   Location: The Paramount Theatre
#   Type: Music
#   Region: Downtown
#
# Details for Tourist and Amtrac (https://visitseattle.org/events/tourist-and-amtrac/):
#   Date: 2/11/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for 6th Annual Sami Film Festival (https://visitseattle.org/events/6th-annual-sami-film-festival/):
#   Date: 2/9/2024 through 2/12/2024
#   Location: Majestic Bay Theatres
#   Type: Museums
#   Region: Fremont / Ballard
#
# Details for Eliades Ochoa (https://visitseattle.org/events/eliades-ochoa/):
#   Date: 2/13/2024
#   Location: The Moore Theatre
#   Type: Music
#   Region: Downtown
#
# Details for K. Wayne Yang (https://visitseattle.org/events/k-wayne-yang/):
#   Date: 2/13/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Juanes (https://visitseattle.org/events/juanes/):
#   Date: 2/14/2024
#   Location: The Moore Theatre
#   Type: Music
#   Region: Downtown
#
# Details for Black Dogs (https://visitseattle.org/events/black-dogs-2/):
#   Date: 2/15/2024
#   Location: Sea Monster Lounge
#   Type: Music
#   Region: Wallingford / Greenlake
#
# Details for Hear Me Talkin’ to You: Womxn and Blues (https://visitseattle.org/events/hear-me-talkin-to-you-womxn-and-blues/):
#   Date: 2/15/2024
#   Location: The Royal Room
#   Type: Music
#   Region: South Seattle
#
# Details for Maddie Zahm (https://visitseattle.org/events/maddie-zahm/):
#   Date: 2/15/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for Silversun Pickups (https://visitseattle.org/events/silversun-pickups/):
#   Date: 2/15/2024
#   Location: The Moore Theatre
#   Type: Music
#   Region: Downtown
#
# Details for The Brodies (https://visitseattle.org/events/the-brodies/):
#   Date: 2/15/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Cory Wong Winter 2024 Tour (https://visitseattle.org/events/cory-wong-winter-2024-tour/):
#   Date: 2/16/2024
#   Location: The Paramount Theatre
#   Type: Music
#   Region: Downtown
#
# Details for Left on Tenth (https://visitseattle.org/events/left-on-tenth/):
#   Date: 2/16/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Marlon Wayans (https://visitseattle.org/events/marlon-wayans/):
#   Date: 2/16/2024
#   Location: The Moore Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for Riley Mulherkar: Album Release Show (https://visitseattle.org/events/riley-mulherkar-album-release-show/):
#   Date: 2/16/2024
#   Location: The Royal Room
#   Type: Music
#   Region: South Seattle
#
# Details for Yeah! (https://visitseattle.org/events/yeah/):
#   Date: 2/16/2024
#   Location: Nectar Lounge
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Circa:Humans 2.0 (https://visitseattle.org/events/circahumans-2-0/):
#   Date: 2/15/2024 through 2/17/2024
#   Location: Meany Center for the Performing Arts
#   Type: Theatre
#   Region: University District
#
# Details for Big Business (https://visitseattle.org/events/big-business/):
#   Date: 2/17/2024
#   Location: Tractor Tavern
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for David Wax Museum (https://visitseattle.org/events/david-wax-museum/):
#   Date: 2/17/2024
#   Location: Fremont Abbey Arts Center
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Jon Batiste (https://visitseattle.org/events/jon-batiste/):
#   Date: 2/17/2024
#   Location: The Paramount Theatre
#   Type: Music
#   Region: Downtown
#
# Details for lespecial (https://visitseattle.org/events/lespecial/):
#   Date: 2/17/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for TobyMac Hits Deep 2024 (https://visitseattle.org/events/tobymac-hits-deep-2024/):
#   Date: 2/17/2024
#   Location: accesso ShoWare Center
#   Type: Music
#   Region: South
#
# Details for A Case for the Existence of God (https://visitseattle.org/events/a-case-for-the-existence-of-god/):
#   Date: 2/2/2024 through 2/18/2024
#   Location: ACT Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for Northwest Flower & Garden Festival (https://visitseattle.org/events/northwest-flower-garden-festival/):
#   Date: 2/14/2024 through 2/18/2024
#   Location: Seattle Convention Center
#   Type: Festivals & Special Events
#   Region: Downtown
#
# Details for The Princess Bride in Concert with the Seattle Symphony (https://visitseattle.org/events/the-princess-bride-in-concert-with-the-seattle-symphony/):
#   Date: 2/14/2024 through 2/18/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Mindi Abair Wine and Jazz Tour 2024 (https://visitseattle.org/events/mindi-abair-wine-and-jazz-tour-2024/):
#   Date: 2/15/2024 through 2/18/2024
#   Location: Dimitriou's Jazz Alley
#   Type: Music
#   Region: Downtown
#
# Details for Madonna (https://visitseattle.org/events/madonna/):
#   Date: 2/17/2024 through 2/18/2024
#   Location: Climate Pledge Arena
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Aqua Fools’ Day (https://visitseattle.org/events/aqua-fools-day/):
#   Date: 2/18/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Dr. Joy Buolamwini (https://visitseattle.org/events/dr-joy-buolamwini/):
#   Date: 2/18/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for La Nef: Red Sky at Night (https://visitseattle.org/events/la-nef-red-sky-at-night/):
#   Date: 2/18/2024
#   Location: Town Hall Seattle
#   Type: Music
#   Region: Downtown
#
# Details for Love Beyond Border (https://visitseattle.org/events/love-beyond-border/):
#   Date: 2/18/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Meet the Author: Maggie Taft, The Chieftain and the Chair (https://visitseattle.org/events/meet-the-author-maggie-taft-the-chieftain-and-the-chair/):
#   Date: 2/18/2024
#   Location: National Nordic Museum
#   Type: Museums
#   Region: Fremont / Ballard
#
# Details for Seattle Kraken vs. Detroit Red Wings (https://visitseattle.org/events/seattle-kraken-vs-detroit-red-wings/):
#   Date: 2/19/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for The Thrifted (https://visitseattle.org/events/the-thrifted/):
#   Date: 2/19/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Black and Boujee (https://visitseattle.org/events/black-and-boujee/):
#   Date: Now through 2/20/2024
#   Location: Bainbridge Island Museum of Art
#   Type: Museums
#   Region: West
#
# Details for From Mozart to Matthews (https://visitseattle.org/events/from-mozart-to-matthews/):
#   Date: 2/20/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Lukas Nelson (https://visitseattle.org/events/lukas-nelson/):
#   Date: 2/20/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Mahogany – smARTfilms: Black Luxury (https://visitseattle.org/events/mahogany-smartfilms-black-luxury/):
#   Date: 2/20/2024
#   Location: Bainbridge Island Museum of Art
#   Type: Film & Media Arts
#   Region: West
#
# Details for Robots Who Paint (https://visitseattle.org/events/robots-who-paint/):
#   Date: 2/20/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Trask (https://visitseattle.org/events/trask/):
#   Date: 2/20/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Wu Han, Philip Setzer & David Finckel (https://visitseattle.org/events/wu-han-philip-setzer-david-finckel/):
#   Date: 2/20/2024
#   Location: Meany Center for the Performing Arts
#   Type: Music
#   Region: University District
#
# Details for The Cookers (https://visitseattle.org/events/the-cookers/):
#   Date: 2/20/2024 through 2/21/2024
#   Location: Dimitriou's Jazz Alley
#   Type: Music
#   Region: Downtown
#
# Details for Cesar Cuauhtemoc Garcia Hernandez (https://visitseattle.org/events/cesar-cuauhtemoc-garcia-hernandez/):
#   Date: 2/21/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Side-by-Side with Seattle Youth Symphony Orchestra (https://visitseattle.org/events/side-by-side-with-seattle-youth-symphony-orchestra/):
#   Date: 2/21/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Bailen (https://visitseattle.org/events/bailen/):
#   Date: 2/22/2024
#   Location: The Crocodile
#   Type: Music
#   Region: Downtown
#
# Details for Dr. Charan Ranganath (https://visitseattle.org/events/dr-charan-ranganath/):
#   Date: 2/22/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Mountain Holler (https://visitseattle.org/events/mountain-holler/):
#   Date: 2/22/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Seattle Kraken vs. Vancouver Canucks (https://visitseattle.org/events/seattle-kraken-vs-vancouver-canucks/):
#   Date: 2/22/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Shabaka (https://visitseattle.org/events/shabaka/):
#   Date: 2/22/2024
#   Location: Town Hall Seattle
#   Type: Music
#   Region: Downtown
#
# Details for Funky Friday with F2D (https://visitseattle.org/events/funky-friday-with-f2d/):
#   Date: Now through 2/23/2024
#   Location: Sea Monster Lounge
#   Type: Music
#   Region: Wallingford / Greenlake
#
# Details for BLACKSTAR SYMPHONY: The Music of David Bowie (https://visitseattle.org/events/blackstar-symphony-the-music-of-david-bowie/):
#   Date: 2/23/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Caligula’s Horse (https://visitseattle.org/events/caligulas-horse/):
#   Date: 2/23/2024
#   Location: El Corazon
#   Type: Music
#   Region: Downtown
#
# Details for Opera Talk: The Making of X (https://visitseattle.org/events/opera-talk-the-making-of-x/):
#   Date: 2/23/2024
#   Location: Opera Center
#   Type: Readings & Lectures
#   Region: Queen Anne / Seattle Center
#
# Details for Tikkadoom and Nick Drummond (https://visitseattle.org/events/tikkadoom-and-nick-drummond/):
#   Date: 2/23/2024
#   Location: The Royal Room
#   Type: Music
#   Region: South Seattle
#
# Details for Wreckno (https://visitseattle.org/events/wreckno/):
#   Date: 2/23/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Kelly Akashi (https://visitseattle.org/events/kelly-akashi/):
#   Date: Now through 2/24/2024
#   Location: Henry Art Gallery
#   Type: Museums
#   Region: University District
#
# Details for The Lower Depths (https://visitseattle.org/events/the-lower-depths/):
#   Date: 2/6/2024 through 2/24/2024
#   Location: Erickson Theatre
#   Type: Theatre
#   Region: Capitol Hill / Central District
#
# Details for Bassekou Kouyate and Vieux Farka Toure (https://visitseattle.org/events/bassekou-kouyate-and-vieux-farka-toure/):
#   Date: 2/22/2024 through 2/24/2024
#   Location: Town Hall Seattle
#   Type: Music
#   Region: Downtown
#
# Details for Crystal Skies (https://visitseattle.org/events/crystal-skies/):
#   Date: 2/24/2024
#   Location: Nectar Lounge
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Dan Brown Wild Symphony (https://visitseattle.org/events/dan-brown-wild-symphony/):
#   Date: 2/24/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Nate Jackson (https://visitseattle.org/events/nate-jackson/):
#   Date: 2/24/2024
#   Location: The Moore Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for Pink Sweat$ (https://visitseattle.org/events/pink-sweat/):
#   Date: 2/24/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Root and Branch (https://visitseattle.org/events/root-and-branch/):
#   Date: 2/24/2024
#   Location: Town Hall Seattle
#   Type: Music
#   Region: Downtown
#
# Details for Seattle Kraken vs. Minnesota Wild (https://visitseattle.org/events/seattle-kraken-vs-minnesota-wild-2/):
#   Date: 2/24/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Small Island Big Song (https://visitseattle.org/events/small-island-big-song/):
#   Date: 2/24/2024
#   Location: Meany Center for the Performing Arts
#   Type: Music
#   Region: University District
#
# Details for Born With Teeth (https://visitseattle.org/events/born-with-teeth/):
#   Date: 2/1/2024 through 2/25/2024
#   Location: ArtsWest Playhouse and Gallery
#   Type: Theatre
#   Region: West Seattle
#
# Details for Once More, Just For You (https://visitseattle.org/events/once-more-just-for-you/):
#   Date: 2/5/2024 through 2/25/2024
#   Location: Seattle Public Theater
#   Type: Theatre
#   Region: Wallingford / Greenlake
#
# Details for Wintergrass Music Festival (https://visitseattle.org/events/wintergrass-music-festival/):
#   Date: 2/22/2024 through 2/25/2024
#   Location: Hyatt Regency Bellevue
#   Type: Festivals & Special Events
#   Region: Bellevue / Eastside
#
# Details for Klezmer Starts Here: The Music of Abe Schwartz (https://visitseattle.org/events/klezmer-starts-here-the-music-of-abe-schwartz/):
#   Date: 2/25/2024
#   Location: The Royal Room
#   Type: Music
#   Region: South Seattle
#
# Details for Telling the Story (https://visitseattle.org/events/telling-the-story/):
#   Date: 2/25/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Cherry Glazerr (https://visitseattle.org/events/cherry-glazerr/):
#   Date: 2/26/2024
#   Location: Neumos
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Dick & Angel Dare to Do It (https://visitseattle.org/events/dick-angel-dare-to-do-it/):
#   Date: 2/26/2024
#   Location: The Paramount Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for Seattle Kraken vs. Boston Bruins (https://visitseattle.org/events/seattle-kraken-vs-boston-bruins/):
#   Date: 2/26/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Hunt for Sleeping Giants | National Geographic Live (https://visitseattle.org/events/hunt-for-sleeping-giants-national-geographic-live/):
#   Date: 2/25/2024 through 2/27/2024
#   Location: Benaroya Hall
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Big Tooth (https://visitseattle.org/events/big-tooth/):
#   Date: 2/27/2024
#   Location: Sea Monster Lounge
#   Type: Music
#   Region: Wallingford / Greenlake
#
# Details for Eric Klinenberg (https://visitseattle.org/events/eric-klinenberg/):
#   Date: 2/27/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Fresh Dressed – smARTfilms: Black Luxury (https://visitseattle.org/events/fresh-dressed-smartfilms-black-luxury/):
#   Date: 2/27/2024
#   Location: Bainbridge Island Museum of Art
#   Type: Museums
#   Region: West
#
# Details for Joy Harjo (https://visitseattle.org/events/joy-harjo/):
#   Date: 2/27/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Anand Gopal (https://visitseattle.org/events/anand-gopal/):
#   Date: 2/28/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Dianne Reeves (https://visitseattle.org/events/dianne-reeves/):
#   Date: 2/28/2024
#   Location: Town Hall Seattle
#   Type: Music
#   Region: Downtown
#
# Details for Kassa Overall (https://visitseattle.org/events/kassa-overall/):
#   Date: 2/28/2024
#   Location: Nectar Lounge
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Playboi Carti (https://visitseattle.org/events/playboi-carti/):
#   Date: 2/28/2024
#   Location: Climate Pledge Arena
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Winter Brilliance (https://visitseattle.org/events/winter-brilliance/):
#   Date: Now through 2/29/2024
#   Location: Chihuly Garden and Glass
#   Type: Museums
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Museum Month (https://visitseattle.org/events/seattle-museum-month/):
#   Date: 2/1/2024 through 2/29/2024
#   Location: Downtown Seattle
#   Type: Museums
#   Region: Downtown
#
# Details for JNA and Tavia Rhodes (https://visitseattle.org/events/jna-and-tavia-rhodes/):
#   Date: 2/29/2024
#   Location: The Royal Room
#   Type: Music
#   Region: South Seattle
#
# Details for Julian Lage (https://visitseattle.org/events/julian-lage/):
#   Date: 2/29/2024
#   Location: Town Hall Seattle
#   Type: Music
#   Region: Downtown
#
# Details for MarchFourth (https://visitseattle.org/events/marchfourth/):
#   Date: 2/29/2024
#   Location: Nectar Lounge
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Seattle Kraken vs. Pittsburgh Penguins (https://visitseattle.org/events/seattle-kraken-vs-pittsburgh-penguins/):
#   Date: 2/29/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for The Human Family (https://visitseattle.org/events/the-human-family-2/):
#   Date: 2/29/2024
#   Location: LANGSTON Seattle
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Enjambre (https://visitseattle.org/events/enjambre/):
#   Date: 3/1/2024
#   Location: Nectar Lounge
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Fall Out Boy (https://visitseattle.org/events/fall-out-boy/):
#   Date: 3/1/2024
#   Location: Climate Pledge Arena
#   Type: Readings & Lectures
#   Region: Queen Anne / Seattle Center
#
# Details for Global Rhythms: Justin Adams and Mauro Durante (https://visitseattle.org/events/global-rhythms-justin-adams-and-mauro-durante/):
#   Date: 3/1/2024
#   Location: Town Hall Seattle
#   Type: Music
#   Region: Downtown
#
# Details for Sloane Crosley with Ben Gibbard (https://visitseattle.org/events/sloane-crosley-with-ben-gibbard/):
#   Date: 3/1/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Tacoma Stars vs. Harrisburg Heat (https://visitseattle.org/events/tacoma-stars-vs-harrisburg-heat/):
#   Date: 3/1/2024
#   Location: accesso ShoWare Center
#   Type: Sports
#   Region: South
#
# Details for Tommy Emmanuel (https://visitseattle.org/events/tommy-emmanuel/):
#   Date: 3/1/2024
#   Location: The Moore Theatre
#   Type: Music
#   Region: Downtown
#
# Details for Facades (https://visitseattle.org/events/facades/):
#   Date: 2/1/2024 through 3/2/2024
#   Location: Harris Harvey Gallery
#   Type: Visual Arts & Galleries
#   Region: Downtown
#
# Details for Conrad Tao’s Playlist (https://visitseattle.org/events/conrad-taos-playlist/):
#   Date: 3/1/2024 through 3/2/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Crypta (https://visitseattle.org/events/crypta/):
#   Date: 3/2/2024
#   Location: El Corazon
#   Type: Music
#   Region: Downtown
#
# Details for Seattle Kraken vs. Edmonton Oilers (https://visitseattle.org/events/seattle-kraken-vs-edmonton-oilers/):
#   Date: 3/2/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Sounders FC vs. Austin FC (https://visitseattle.org/events/seattle-sounders-fc-vs-austin-fc/):
#   Date: 3/2/2024
#   Location: Lumen Field
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Emerald City Comic Con (https://visitseattle.org/events/emerald-city-comic-con/):
#   Date: 2/29/2024 through 3/3/2024
#   Location: Seattle Convention Center
#   Type: Festivals & Special Events
#   Region: Downtown
#
# Details for Briscoe (https://visitseattle.org/events/briscoe/):
#   Date: 3/3/2024
#   Location: Tractor Tavern
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Tacoma Stars vs. Harrisburg Heat (https://visitseattle.org/events/tacoma-stars-vs-harrisburg-heat-2/):
#   Date: 3/3/2024
#   Location: accesso ShoWare Center
#   Type: Music
#   Region: South
#
# Details for Eve’s Bayou – smARTfilms: Black Luxury (https://visitseattle.org/events/eves-bayou-smartfilms-black-luxury/):
#   Date: 3/5/2024
#   Location: Bainbridge Island Museum of Art
#   Type: Museums
#   Region: West
#
# Details for Atlus (https://visitseattle.org/events/atlus/):
#   Date: 3/7/2024
#   Location: Nectar Lounge
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Calidore Quartet & Abeo Quartet (https://visitseattle.org/events/calidore-quartet-abeo-quartet/):
#   Date: 3/8/2024
#   Location: 415 Westlake
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Holding / Movement (https://visitseattle.org/events/holding-movement/):
#   Date: 3/8/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Seattle Kraken vs. Winnipeg Jets (https://visitseattle.org/events/seattle-kraken-vs-winnipeg-jets/):
#   Date: 3/8/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for X:The Life and Times of Malcolm X (https://visitseattle.org/events/xthe-life-and-times-of-malcolm-x/):
#   Date: 2/24/2024 through 3/9/2024
#   Location: Marion Oliver McCaw Hall
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Bach St. John Passion (https://visitseattle.org/events/bach-st-john-passion/):
#   Date: 3/7/2024 through 3/9/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Ariel Pink (https://visitseattle.org/events/ariel-pink/):
#   Date: 3/9/2024
#   Location: El Corazon
#   Type: Music
#   Region: Downtown
#
# Details for Helene Grimaud (https://visitseattle.org/events/helene-grimaud/):
#   Date: 3/9/2024
#   Location: Meany Center for the Performing Arts
#   Type: Music
#   Region: University District
#
# Details for Josiah and the Bonnevilles (https://visitseattle.org/events/josiah-and-the-bonnevilles/):
#   Date: 3/9/2024
#   Location: Barboza
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Mahan Esfahan (https://visitseattle.org/events/mahan-esfahan/):
#   Date: 3/9/2024
#   Location: Town Hall Seattle
#   Type: Music
#   Region: Downtown
#
# Details for Positive Fragmentation (https://visitseattle.org/events/positive-fragmentation/):
#   Date: Now through 3/10/2024
#   Location: Bellevue Arts Museum
#   Type: Museums
#   Region: Bellevue / Eastside
#
# Details for Antonio M. Gomez: LINEAJES (https://visitseattle.org/events/antonio-m-gomez-lineajes/):
#   Date: Now through 3/10/2024
#   Location: Frye Art Museum
#   Type: Museums
#   Region: Capitol Hill / Central District
#
# Details for Soren Solkaer: Sort Sol (https://visitseattle.org/events/soren-solkaer-sort-sol/):
#   Date: Now through 3/10/2024
#   Location: National Nordic Museum
#   Type: Museums
#   Region: Fremont / Ballard
#
# Details for Luchadora! (https://visitseattle.org/events/luchadora/):
#   Date: 2/22/2024 through 3/10/2024
#   Location: Seattle Children's Theatre
#   Type: Theatre
#   Region: Queen Anne / Seattle Center
#
# Details for Wild Cats Revealed | National Geographic Live (https://visitseattle.org/events/wild-cats-revealed-national-geographic-live/):
#   Date: 3/10/2024 through 3/12/2024
#   Location: Benaroya Hall
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Seattle Kraken vs. Vegas Golden Knights (https://visitseattle.org/events/seattle-kraken-vs-vegas-golden-knights/):
#   Date: 3/12/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Kraken vs. Washington Capitals (https://visitseattle.org/events/seattle-kraken-vs-washington-capitals/):
#   Date: 3/14/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Autoheart (https://visitseattle.org/events/autoheart/):
#   Date: 3/15/2024
#   Location: El Corazon
#   Type: Music
#   Region: Downtown
#
# Details for The Snuts (https://visitseattle.org/events/the-snuts/):
#   Date: 3/15/2024
#   Location: Barboza
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Mark Morris Dance Group: The Look of Love (https://visitseattle.org/events/mark-morris-dance-group-the-look-of-love/):
#   Date: 3/14/2024 through 3/16/2024
#   Location: Meany Center for the Performing Arts
#   Type: Music
#   Region: University District
#
# Details for Sibelius & Nielsen (https://visitseattle.org/events/sibelius-nielsen/):
#   Date: 3/14/2024 through 3/16/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Tacoma Stars vs. Chihuahua Savage (https://visitseattle.org/events/tacoma-stars-vs-chihuahua-savage/):
#   Date: 3/15/2024 through 3/16/2024
#   Location: accesso ShoWare Center
#   Type: Sports
#   Region: South
#
# Details for Seattle Kraken vs. Nashville Predators (https://visitseattle.org/events/seattle-kraken-vs-nashville-predators/):
#   Date: 3/16/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Sounders FC vs. Colorado Rapids (https://visitseattle.org/events/seattle-sounders-fc-vs-colorado-rapids/):
#   Date: 3/16/2024
#   Location: Lumen Field
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Native Portraiture: Power and Perception (https://visitseattle.org/events/native-portraiture-power-and-perception/):
#   Date: Now through 3/17/2024
#   Location: Tacoma Art Museum
#   Type: Museums
#   Region: South
#
# Details for Places to Call Home: Settlements in the West (https://visitseattle.org/events/places-to-call-home-settlements-in-the-west/):
#   Date: Now through 3/17/2024
#   Location: Tacoma Art Museum
#   Type: Museums
#   Region: South
#
# Details for Nobody Lives Here (https://visitseattle.org/events/nobody-lives-here/):
#   Date: Now through 3/17/2024
#   Location: Wing Luke Museum
#   Type: Museums
#   Region: International District
#
# Details for Rootabaga Country (https://visitseattle.org/events/rootabaga-country/):
#   Date: 3/8/2024 through 3/17/2024
#   Location: Opera Center
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Kraken vs. Buffalo Sabres (https://visitseattle.org/events/seattle-kraken-vs-buffalo-sabres/):
#   Date: 3/18/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Tacoma Stars vs. Empire Strykers (https://visitseattle.org/events/tacoma-stars-vs-empire-strykers-2/):
#   Date: 3/23/2024
#   Location: accesso ShoWare Center
#   Type: Sports
#   Region: South
#
# Details for Something’s Afoot (https://visitseattle.org/events/somethings-afoot/):
#   Date: 3/1/2024 through 3/24/2024
#   Location: The 5th Avenue Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for One Thousand Pieces (https://visitseattle.org/events/one-thousand-pieces/):
#   Date: 3/15/2024 through 3/24/2024
#   Location: Marion Oliver McCaw Hall
#   Type: Dance
#   Region: Queen Anne / Seattle Center
#
# Details for Simon Trpceski Plays Tchaikovsky (https://visitseattle.org/events/simon-trpceski-plays-tchaikovsky/):
#   Date: 3/21/2024 through 3/24/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Celebrate Holi! Spring Festival of Colors from South Asia (https://visitseattle.org/events/celebrate-holi-spring-festival-of-colors-from-south-asia/):
#   Date: 3/24/2024
#   Location: Burke Museum
#   Type: Museums
#   Region: University District
#
# Details for Seattle Kraken vs. Montreal Canadiens (https://visitseattle.org/events/seattle-kraken-vs-montreal-canadiens/):
#   Date: 3/24/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Kraken vs. Anaheim Ducks (https://visitseattle.org/events/seattle-kraken-vs-anaheim-ducks/):
#   Date: 3/26/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Kraken vs. Anaheim Ducks (https://visitseattle.org/events/seattle-kraken-vs-anaheim-ducks-2/):
#   Date: 3/28/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Tim McGraw (https://visitseattle.org/events/tim-mcgraw/):
#   Date: 3/29/2024
#   Location: Climate Pledge Arena
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Harold and the Purple Crayon (https://visitseattle.org/events/harold-and-the-purple-crayon/):
#   Date: 3/23/2024 through 3/30/2024
#   Location: Marion Oliver McCaw Hall
#   Type: Dance
#   Region: Queen Anne / Seattle Center
#
# Details for Monster Jam (https://visitseattle.org/events/monster-jam/):
#   Date: 3/30/2024
#   Location: Lumen Field
#   Type: Festivals & Special Events
#   Region: Pioneer Square
#
# Details for Seattle Kraken vs. Dallas Stars (https://visitseattle.org/events/seattle-kraken-vs-dallas-stars/):
#   Date: 3/30/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Illuminate: Glass Art for Early Learners (https://visitseattle.org/events/illuminate-glass-art-for-early-learners/):
#   Date: Now through 3/31/2024
#   Location: Museum of Glass
#   Type: Museums
#   Region: South
#
# Details for Al Young’s 1970 Dodge Challenger Drag Racer (https://visitseattle.org/events/al-youngs-1970-dodge-challenger-drag-racer/):
#   Date: Now through 3/31/2024
#   Location: Museum of History & Industry
#   Type: Museums
#   Region: Queen Anne / Seattle Center
#
# Details for Shine On Seattle (https://visitseattle.org/events/shine-on-seattle/):
#   Date: Now through 3/31/2024
#   Location: Pioneer Square
#   Type: Festivals & Special Events
#   Region: Pioneer Square
#
# Details for Sanctuary City (https://visitseattle.org/events/sanctuary-city/):
#   Date: 3/1/2024 through 3/31/2024
#   Location: Seattle Rep
#   Type: Theatre
#   Region: Queen Anne / Seattle Center
#
# Details for Stew (https://visitseattle.org/events/stew/):
#   Date: 3/15/2024 through 3/31/2024
#   Location: ACT Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for Luis Miguel (https://visitseattle.org/events/luis-miguel/):
#   Date: 4/4/2024
#   Location: Climate Pledge Arena
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Taylor Raven and Duke Kim in Recital (https://visitseattle.org/events/taylor-raven-and-duke-kim-in-recital/):
#   Date: 4/4/2024
# ...
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Sounders FC vs. Real Salt Lake (https://visitseattle.org/events/seattle-sounders-fc-vs-real-salt-lake/):
#   Date: 5/29/2024
#   Location: Lumen Field
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Unriveled (https://visitseattle.org/events/unriveled/):
#   Date: 5/10/2024 through 6/2/2024
#   Location: Seattle Public Theater
#   Type: Theatre
#   Region: Wallingford / Greenlake
#
# Details for Seattle Storm vs. Phoenix Mercury (https://visitseattle.org/events/seattle-storm-vs-phoenix-mercury-2/):
#   Date: 6/4/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for George Balenchine’s Coppelia (https://visitseattle.org/events/george-balenchines-coppelia/):
#   Date: 5/31/2024 through 6/9/2024
#   Location: Marion Oliver McCaw Hall
#   Type: Dance
#   Region: Queen Anne / Seattle Center
#
# Details for Jan Lisiecki Plays Prokofiev (https://visitseattle.org/events/jan-lisiecki-plays-prokofiev/):
#   Date: 6/6/2024 through 6/9/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Seattle Storm vs. Los Angeles Sparks (https://visitseattle.org/events/seattle-storm-vs-los-angeles-sparks-2/):
#   Date: 6/11/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Beethoven Symphony No. 5 (https://visitseattle.org/events/beethoven-symphony-no-5/):
#   Date: 6/13/2024 through 6/15/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Elizabeth Malaska: All Be Your Mirror (https://visitseattle.org/events/elizabeth-malaska-all-be-your-mirror/):
#   Date: Now through 6/16/2024
#   Location: Seattle Art Museum
#   Type: Museums
#   Region: Downtown
#
# Details for Joshua Bell Plays Elements Concerto (https://visitseattle.org/events/joshua-bell-plays-elements-concerto/):
#   Date: 6/20/2024 through 6/22/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Seattle Sounders FC vs. Minnesota United FC (https://visitseattle.org/events/seattle-sounders-fc-vs-minnesota-united-fc/):
#   Date: 6/22/2024
#   Location: Lumen Field
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Together Again, Again! (https://visitseattle.org/events/together-again-again/):
#   Date: 5/31/2024 through 6/23/2024
#   Location: Seattle Rep
#   Type: Theatre
#   Region: Queen Anne / Seattle Center
#
# Details for 2024 KPMG Women’s PGA Championship (https://visitseattle.org/events/2024-kpmg-womens-pga-championship/):
#   Date: 6/20/2024 through 6/23/2024
#   Location: Sahalee Country Club
#   Type: Sports
#   Region: Bellevue / Eastside
#
# Details for Lip Sync for Our Rights (https://visitseattle.org/events/lip-sync-for-our-rights/):
#   Date: 6/22/2024 through 6/23/2024
#   Location: Marion Oliver McCaw Hall
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Storm vs. Connecticut Sun (https://visitseattle.org/events/seattle-storm-vs-connecticut-sun/):
#   Date: 6/23/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Storm vs. Indiana Fever (https://visitseattle.org/events/seattle-storm-vs-indiana-fever-2/):
#   Date: 6/27/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Company (https://visitseattle.org/events/company/):
#   Date: 6/23/2024 through 6/28/2024
#   Location: The Paramount Theatre
#   Type: Music
#   Region: Downtown
#
# Details for Seattle Storm vs. Dallas Wings (https://visitseattle.org/events/seattle-storm-vs-dallas-wings/):
#   Date: 6/29/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Sounders FC vs. Chicago Fire FC (https://visitseattle.org/events/sounders-fc-vs-chicago-fire-fc/):
#   Date: 6/29/2024
#   Location: Lumen Field
#   Type: Sports
#   Region: Pioneer Square
#
# Details for 2024 University of Washington MFA + MDes Thesis Exhibition (https://visitseattle.org/events/2024-university-of-washington-mfa-mdes-thesis-exhibition/):
#   Date: 5/24/2024 through 6/30/2024
#   Location: Henry Art Gallery
#   Type: Museums
#   Region: University District
#
# Details for Spring Awakening (https://visitseattle.org/events/spring-awakening/):
#   Date: 6/7/2024 through 6/30/2024
#   Location: The 5th Avenue Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for Girl From The North Country (https://visitseattle.org/events/girl-from-the-north-country/):
#   Date: 6/25/2024 through 6/30/2024
#   Location: The Paramount Theatre
#   Type: Music
#   Region: Downtown
#
# Details for Seattle Storm vs Dallas Wings (https://visitseattle.org/events/seattle-storm-vs-dallas-wings-2/):
#   Date: 7/1/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Storm vs. Chicago Sky (https://visitseattle.org/events/seattle-storm-vs-chicago-sky-2/):
#   Date: 7/5/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Anida Yoeu Ali: Hybrid Skin, Mythical Presence (https://visitseattle.org/events/anida-yoeu-ali-hybrid-skin-mythical-presence/):
#   Date: Now through 7/7/2024
#   Location: Seattle Asian Art Museum
#   Type: Museums
#   Region: Capitol Hill / Central District
#
# Details for Seattle Storm vs.Chicago Sky (https://visitseattle.org/events/seattle-storm-vs-chicago-sky/):
#   Date: 7/7/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Storm vs. Las Vegas Aces (https://visitseattle.org/events/seattle-storm-vs-las-vegas-aces/):
#   Date: 7/10/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Storm vs. Minnesota Lynx (https://visitseattle.org/events/seattle-storm-vs-minnesota-lynx-2/):
#   Date: 7/12/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Storm vs. Atlanta Dream (https://visitseattle.org/events/seattle-storm-vs-atlanta-dream-2/):
#   Date: 7/14/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Sounders FC vs. Los Angeles FC (https://visitseattle.org/events/seattle-sounders-fc-vs-los-angeles-fc/):
#   Date: 7/20/2024
#   Location: Lumen Field
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Nordic Utopia: African Americans in the 20th Century (https://visitseattle.org/events/nordic-utopia-african-americans-in-the-20th-century/):
#   Date: 3/22/2024 through 7/21/2024
#   Location: National Nordic Museum
#   Type: Museums
#   Region: Fremont / Ballard
#
# Details for Clue (https://visitseattle.org/events/clue/):
#   Date: 7/9/2024 through 7/21/2024
#   Location: The 5th Avenue Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for Be Water, My Friend: The Teachings Of Bruce Lee (https://visitseattle.org/events/be-water-my-friend-the-teachings-of-bruce-lee/):
#   Date: Now through 7/28/2024
#   Location: Wing Luke Museum
#   Type: Museums
#   Region: International District
#
# Details for Olivia Rodrigo (https://visitseattle.org/events/olivia-rodrigo/):
#   Date: 8/6/2024 through 8/7/2024
#   Location: Climate Pledge Arena
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Storm vs. Washington Mystics (https://visitseattle.org/events/seattle-storm-vs-washington-mystics/):
#   Date: 8/26/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Storm vs. Atlanta Dream (https://visitseattle.org/events/seattle-storm-vs-atlanta-dream/):
#   Date: 8/28/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Storm vs. New York Liberty (https://visitseattle.org/events/seattle-storm-vs-new-york-liberty/):
#   Date: 8/30/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Hidden Worlds: The Films of LAIKA (https://visitseattle.org/events/hidden-worlds-the-films-of-laika/):
#   Date: Now through 8/31/2024
#   Location: MoPOP Museum of Pop Culture
#   Type: Museums
#   Region: Queen Anne / Seattle Center
#
# Details for Poke in the Eye: Art of the West Coast Counterculture (https://visitseattle.org/events/poke-in-the-eye-art-of-the-west-coast-counterculture/):
#   Date: 6/21/2024 through 9/2/2024
#   Location: Seattle Art Museum
#   Type: Museums
#   Region: Downtown
#
# Details for Chicago and Earth, Wind & Fire, (https://visitseattle.org/events/chicago-and-earth-wind-fire/):
#   Date: 9/3/2024
#   Location: Climate Pledge Arena
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Storm vs. Phoenix Mercury (https://visitseattle.org/events/seattle-storm-vs-phoenix-mercury/):
#   Date: 9/7/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Sound Check! The Music We Make (https://visitseattle.org/events/sound-check-the-music-we-make/):
#   Date: Now through 9/14/2024
#   Location: Wing Luke Museum
#   Type: Museums
#   Region: International District
#
# Details for Seattle Sounders FC vs. Sporting Kansas City (https://visitseattle.org/events/seattle-sounders-fc-vs-sporting-kansas-city/):
#   Date: 9/15/2024
#   Location: Lumen Field
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Seattle Storm vs. Los Angeles Sparks (https://visitseattle.org/events/seattle-storm-vs-los-angeles-sparks/):
#   Date: 9/15/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Storm vs. Las Vegas Aces (https://visitseattle.org/events/seattle-storm-vs-las-vegas-aces-2/):
#   Date: 9/17/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Sounders FC vs. San Jose Earthquakes (https://visitseattle.org/events/seattle-sounders-fc-vs-san-jose-earthquakes/):
#   Date: 9/18/2024
#   Location: Lumen Field
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Seatle Sounders FC vs. Houston Dynamo (https://visitseattle.org/events/seatle-sounders-fc-vs-houston-dynamo/):
#   Date: 9/28/2024
#   Location: Lumen Field
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Raul de Nieves (https://visitseattle.org/events/raul-de-nieves/):
#   Date: Now through 9/30/2024
#   Location: Henry Art Gallery
#   Type: Museums
#   Region: University District
#
# Details for Seattle Sounders FC vs. Portland Timbers (https://visitseattle.org/events/seattle-sounders-fc-vs-portland-timbers/):
#   Date: 10/19/2024
#   Location: Lumen Field
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Sebastian Maniscalco (https://visitseattle.org/events/sebastian-maniscalco/):
#   Date: 10/25/2024
#   Location: Climate Pledge Arena
#   Type: Theatre
#   Region: Queen Anne / Seattle Center
#
# Details for Frye Salon (https://visitseattle.org/events/frye-salon/):
#   Date: Now through 10/27/2024
#   Location: Frye Art Museum
#   Type: Museums
#   Region: Capitol Hill / Central District
#
# Details for On Native Land: Landscapes from the Haub Family Collection (https://visitseattle.org/events/on-native-land-landscapes-from-the-haub-family-collection/):
#   Date: Now through 11/17/2024
#   Location: Tacoma Art Museum
#   Type: Museums
#   Region: South
#
# Details for Joyce J. Scott: Walk a Mile in My Dreams (https://visitseattle.org/events/joyce-j-scott-walk-a-mile-in-my-dreams/):
#   Date: 10/17/2024 through 1/20/2025
#   Location: Seattle Art Museum
#   Type: Museums
#   Region: Downtown
#
# Details for Washi Transformed New Expressions in Japanese Paper (https://visitseattle.org/events/washi-transformed-new-expressions-in-japanese-paper/):
#   Date: 2/2/2024 through 4/26/2026
#   Location: Bellevue Arts Museum
#   Type: Museums
#   Region: Bellevue / Eastside
#
# Details for Explore The Market (https://visitseattle.org/events/explore-the-market/):
#   Date: Ongoing
#   Location: Pike Place Market
#   Type: Festivals & Special Events
#   Region: Downtown
#
# Details for Olympic Sculpture Park (https://visitseattle.org/events/olympic-sculpture-park/):
#   Date: Ongoing
#   Location: Olympic Sculpture Park
#   Type: Visual Arts & Galleries
#   Region: Downtown
#
# Details for Infinite Worlds of Science Fiction (https://visitseattle.org/events/infinite-worlds-of-science-fiction/):
#   Date: Ongoing
#   Location: MoPOP Museum of Pop Culture
#   Type: Museums
#   Region: Queen Anne / Seattle Center
#
# Details for Wild Blue Angel: Hendrix Abroad, 1966-70 (https://visitseattle.org/events/wild-blue-angel-hendrix-abroad-1966-70/):
#   Date: Ongoing
#   Location: MoPOP Museum of Pop Culture
#   Type: Museums
#   Region: Queen Anne / Seattle Center
#
# Details for John Grade: Middle Fork (https://visitseattle.org/events/john-grade-middle-fork/):
#   Date: Ongoing
#   Location: Seattle Art Museum
#   Type: Museums
#   Region: Downtown
#
# Details for Scared to Death: The Thrill of Horror Film (https://visitseattle.org/events/scared-to-death-the-thrill-of-horror-film/):
#   Date: Ongoing
#   Location: MoPOP Museum of Pop Culture
#   Type: Museums
#   Region: Queen Anne / Seattle Center
#
# Details for Nirvana: Taking Punk To the Masses (https://visitseattle.org/events/nirvana-taking-punk-to-the-masses/):
#   Date: Ongoing
#   Location: MoPOP Museum of Pop Culture
#   Type: Museums
#   Region: Queen Anne / Seattle Center
#
# Details for Vietnam Divided: War Above Southeast Asia (https://visitseattle.org/events/vietnam-divided-war-above-southeast-asia/):
#   Date: Ongoing
#   Location: The Museum of Flight
#   Type: Museums
#   Region: South Seattle
#
# Details for Science Fiction and Fantasy Hall of Fame (https://visitseattle.org/events/science-fiction-and-fantasy-hall-of-fame/):
#   Date: Ongoing
#   Location: MoPOP Museum of Pop Culture
#   Type: Museums
#   Region: Queen Anne / Seattle Center
#
# Details for Cambodian Cultural Museum and Killing Fields Memorial (https://visitseattle.org/events/cambodian-cultural-museum-and-killing-fields-memorial/):
#   Date: Ongoing
#   Location: Wing Luke Museum
#   Type: Museums
#   Region: International District
#
# Details for Honoring Our Journey (https://visitseattle.org/events/honoring-our-journey/):
#   Date: Ongoing
#   Location: Wing Luke Museum
#   Type: Museums
#   Region: International District
#
# Details for Spotlight on Dale Chihuly: Works from Museum of Glass Permanent Collection (https://visitseattle.org/events/spotlight-on-dale-chihuly-works-from-museum-of-glass-permanent-collection/):
#   Date: Ongoing
#   Location: Museum of Glass
#   Type: Museums
#   Region: South
#
# Details for Great Hall of Washington History (https://visitseattle.org/events/great-hall-of-washington-history/):
#   Date: Ongoing
#   Location: Washington State History Museum
#   Type: Museums
#   Region: South
#
# Details for Humboldt Penguin Exhibit (https://visitseattle.org/events/humboldt-penguin-exhibit/):
#   Date: Ongoing
#   Location: Woodland Park Zoo
#   Type: Museums
#   Region: Wallingford / Greenlake
#
# Details for Giant Pacific Octopus (https://visitseattle.org/events/giant-pacific-octopus/):
#   Date: Ongoing
#   Location: Seattle Aquarium
#   Type: Museums
#   Region: Downtown
#
# Details for Meet our Marine Mammals (https://visitseattle.org/events/meet-our-marine-mammals/):
#   Date: Ongoing
#   Location: Seattle Aquarium
#   Type: Museums
#   Region: Downtown
#
# Details for Window on Washington Waters (https://visitseattle.org/events/window-on-washington-waters/):
#   Date: Ongoing
#   Location: Seattle Aquarium
#   Type: Museums
#   Region: Downtown
#
# Details for Guitar Gallery (https://visitseattle.org/events/guitar-gallery/):
#   Date: Ongoing
#   Location: MoPOP Museum of Pop Culture
#   Type: Museums
#   Region: Queen Anne / Seattle Center
#
# Details for Nordic Journeys (https://visitseattle.org/events/nordic-journeys/):
#   Date: Ongoing
#   Location: National Nordic Museum
#   Type: Museums
#   Region: Fremont / Ballard
#
# Details for Baird’s beaked whale (https://visitseattle.org/events/bairds-beaked-whale/):
#   Date: Ongoing
#   Location: Burke Museum
#   Type: Museums
#   Region: University District
#
# Details for Amazing Life (https://visitseattle.org/events/amazing-life/):
#   Date: Ongoing
#   Location: Burke Museum
#   Type: Museums
#   Region: University District
#
# Event details stored in events.csv

# %% [markdown]
# # Weather API

# %%
import requests

# %%
url = "https://api.weather.gov/points/39.7456,-97.0892"
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
res.text

# %%
point_dict = res.json()
point_dict

# %%
point_dict.keys()

# %%
forcast_url = point_dict['properties']['forecast']
forcast_url

# %%
res = requests.get(forcast_url)
res.json()

# %%
from logging import exception
def get_weathers(latitude, longitude, date):
  try:


        # Format coordinates without extra characters
        coordinates = f'{latitude},{longitude}'

        # Construct API URL
        api_url = f'https://api.weather.gov/points/{coordinates}'

        response = requests.get(api_url)
        response.raise_for_status()
        data = response.json()
        point_dict = response.json()
        point_dict.keys()
        forcast_url = point_dict['properties']['forecast']
        forcast_url
        response = requests.get(forcast_url)
        response.json()
        forecast_data = response.json()


        print(response.json())
        return response.json()

  except requests.exceptions.HTTPError as e:
        print(f"Error fetching weather data: {e}")
        return None
  except (KeyError, ValueError, TypeError) as e:
        print(f"Unexpected response format from weather API: {e}")
        return None
  except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

# %%
import requests
import json

def get_weather(latitude, longitude, date):
    try:
        # Format coordinates without extra characters
        coordinates = f'{latitude},{longitude}'

        # Construct API URL for the points endpoint
        api_url = f'https://api.weather.gov/points/{coordinates}'

        # Make request to points endpoint
        response = requests.get(api_url)
        response.raise_for_status()
        point_data = response.json()

        # Extract forecast URL from the points data
        forecast_url = point_data['properties']['forecast']

        # Make request to forecast endpoint
        response = requests.get(forecast_url)
        response.raise_for_status()
        forecast_data = response.json()

        # Extract the daytime forecast for the specified date
        periods = forecast_data.get('properties', {}).get('periods', [])
        is_daytime_values = []

        for period in periods:
            start_time = period.get('startTime', '')
            start_date = start_time.split('T')[0]

            # Print for debugging


            # Check if the period corresponds to the specified date
            if start_date == date:
                is_daytime_values.append(period.get('isDaytime', False))

        return daytime_values

    except requests.exceptions.HTTPError as e:
        print(f"Error fetching weather data: {e}")
        return None
    except (KeyError, ValueError, TypeError) as e:
        print(f"Unexpected response format from weather API: {e}")
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

# Example usage:
#latitude = 47.6090191
#longitude = -122.32993774092222
#date = '2024-01-28'  # Specify the date in 'YYYY-MM-DD' format

#daytime_values = get_weather(latitude, longitude, date)
#print("Daytime Values:")
#print(daytime_values)

# %% [markdown]
# The weather API requres lat, lon information, but we only have the location name...
#
# Let's use the OpenStreetMap API to get the lat, lon information from location name.

# %% [markdown]
# # OpenStreeetMap Geocoding API

# %%
# location name to lat lon

# Option 1: just string manipulation
base_url = "https://nominatim.openstreetmap.org/search.php"
query_params_str = "?q=Wallingford%2C+Seattle&format=jsonv2"
ful_url = base_url + query_params_str

# Option 2: use dictionary to represent query params
#           use requests.get(url, params=query_params) to attach the query param dict
query_params = {
    "q": "Wallingford, Seattle",
    "format": "jsonv2"
}

res = requests.get(base_url, params=query_params)
res.json()
# Out:
# [{'place_id': 312844859,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 150973716,
#   'lat': '47.6594631',
#   'lon': '-122.3343417',
#   'category': 'place',
#   'type': 'suburb',
#   'place_rank': 19,
#   'importance': 0.3131791431958073,
#   'addresstype': 'suburb',
#   'name': 'Wallingford',
#   'display_name': 'Wallingford, Seattle, King County, Washington, 98015, United States',
#   'boundingbox': ['47.6394631', '47.6794631', '-122.3543417', '-122.3143417']}]

# %%
import requests
from bs4 import BeautifulSoup
from geopy.geocoders import Nominatim  # Add this line
import csv
from datetime import datetime



# Function to get location coordinates using Nominatim
def get_location_coordinates(location):
  try:
    geolocator = Nominatim(user_agent="event_scraper")
    location_info = geolocator.geocode(location)
    if location_info:
        return location_info.latitude, location_info.longitude
    return None, None
  except Exception as e:
        print(f"An error occurred while getting location coordinates: {e}")
        return None, None

# %% [markdown]
# Now we have the lat, lon information for a location, we can use the Weather.gov API to get the weather information.

# %%
# Store event details with location and weather in a CSV file
csv_file_path = 'events_with_location_and_weather.csv'
fields = ['Name', 'Date', 'Location', 'Type', 'Region', 'URL', 'Latitude', 'Longitude', 'Weather']
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fields)
    writer.writeheader()

    for event_details in all_event_details:
        latitude, longitude = get_location_coordinates(event_details['Location'])

        weather = get_weather(latitude, longitude, event_details['Date'])
        print(weather)



        if latitude is not None and longitude is not None:


            writer.writerow({
                'Name': event_details['Name'],
                'Date': event_details['Date'],
                'Location': event_details['Location'],
                'Type': event_details['Type'],
                'Region': event_details['Region'],
                'Weather': weather,
                'Latitude': latitude,
                'Longitude': longitude,

            })
        else:
            print(f"Unable to get location coordinates for {event_details['Location']}")

print(f"Event details with location and weather stored in {csv_file_path}")
# Out:
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/52.9517,-1.1451
# None
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/None,None
# None
# Unable to get location coordinates for The Neptune Theatre
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/None,None
# None
# Unable to get location coordinates for Meany Center for the Performing Arts
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/-13.2489,-41.0276
# None
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/-13.2489,-41.0276
# None
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/50.2623,-5.0548
# None
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/-13.2489,-41.0276
# None
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/-5.2464,-78.97
# None
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/None,None
# None
# Unable to get location coordinates for The Neptune Theatre
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/None,None
# None
# Unable to get location coordinates for The Neptune Theatre
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/None,None
# None
# Unable to get location coordinates for The Neptune Theatre
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/-13.2489,-41.0276
# None
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/None,None
# None
# Unable to get location coordinates for Majestic Bay Theatres
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/None,None
# None
# Unable to get location coordinates for The Neptune Theatre
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/None,None
# None
# Unable to get location coordinates for Meany Center for the Performing Arts
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/None,None
# None
# Unable to get location coordinates for Meany Center for the Performing Arts
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/-5.2464,-78.97
# None
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/44.4336,26.0791
# None
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/None,None
# None
# Unable to get location coordinates for Meany Center for the Performing Arts
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/None,None
# None
# Unable to get location coordinates for ArtsWest Playhouse and Gallery
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/None,None
# None
# Unable to get location coordinates for Harris Harvey Gallery
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/-5.2464,-78.97
# None
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/-5.2464,-78.97
# None
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/None,None
# None
# Unable to get location coordinates for Meany Center for the Performing Arts
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/-13.2489,-41.0276
# None
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/-21.267,55.4114
# None
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/-5.2464,-78.97
# None
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/-13.2489,-41.0276
# None
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/None,None
# None
# Unable to get location coordinates for Meany Center for the Performing Arts
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/44.4336,26.0791
# None
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/44.4336,26.0791
# None
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/None,None
# None
# Unable to get location coordinates for Cornish Playhouse at Seattle Center
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Error fetching weather data: 404 Client Error: Not Found for url: https://api.weather.gov/points/-21.267,55.4114
# None
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# [False, True, False]
# Event details with location and weather stored in events_with_location_and_weather.csv

# %%
import requests
import json

def get_weather(latitude, longitude, date):
    try:
        # Format coordinates without extra characters
        coordinates = f'{latitude},{longitude}'

        # Construct API URL for the points endpoint
        api_url = f'https://api.weather.gov/points/{coordinates}'

        # Make request to points endpoint
        response = requests.get(api_url)
        response.raise_for_status()
        point_data = response.json()

        # Extract forecast URL from the points data
        forecast_url = point_data['properties']['forecast']

        # Make request to forecast endpoint
        response = requests.get(forecast_url)
        response.raise_for_status()
        forecast_data = response.json()

        # Extract the daytime forecast for the specified date
        periods = forecast_data.get('properties', {}).get('periods', [])
        is_daytime_values = []

        for period in periods:
            start_time = period.get('startTime', '')
            start_date = start_time.split('T')[0]

            # Print for debugging
            print(f"Checking period: {start_time}, Start Date: {start_date}")

            # Check if the period corresponds to the specified date
            if start_date == date:
                is_daytime_values.append(period.get('isDaytime', False))

        return is_daytime_values

    except requests.exceptions.HTTPError as e:
        print(f"Error fetching weather data: {e}")
        return None
    except (KeyError, ValueError, TypeError) as e:
        print(f"Unexpected response format from weather API: {e}")
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

# Example usage:
latitude = 47.6090191
longitude = -122.32993774092222
date = '2024-01-28'  # Specify the date in 'YYYY-MM-DD' format

daytime_values = get_weather(latitude, longitude, date)
print("Daytime Values:")
print(daytime_values)
# Out:
# Checking period: 2024-01-28T02:00:00-08:00, Start Date: 2024-01-28
# Checking period: 2024-01-28T06:00:00-08:00, Start Date: 2024-01-28
# Checking period: 2024-01-28T18:00:00-08:00, Start Date: 2024-01-28
# Checking period: 2024-01-29T06:00:00-08:00, Start Date: 2024-01-29
# Checking period: 2024-01-29T18:00:00-08:00, Start Date: 2024-01-29
# Checking period: 2024-01-30T06:00:00-08:00, Start Date: 2024-01-30
# Checking period: 2024-01-30T18:00:00-08:00, Start Date: 2024-01-30
# Checking period: 2024-01-31T06:00:00-08:00, Start Date: 2024-01-31
# Checking period: 2024-01-31T18:00:00-08:00, Start Date: 2024-01-31
# Checking period: 2024-02-01T06:00:00-08:00, Start Date: 2024-02-01
# Checking period: 2024-02-01T18:00:00-08:00, Start Date: 2024-02-01
# Checking period: 2024-02-02T06:00:00-08:00, Start Date: 2024-02-02
# Checking period: 2024-02-02T18:00:00-08:00, Start Date: 2024-02-02
# Checking period: 2024-02-03T06:00:00-08:00, Start Date: 2024-02-03
# Daytime Values:
# [False, True, False]
