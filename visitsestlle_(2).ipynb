# %%
# !pip install -r requirements.txt
# !pip install html2text
# !pip install requests-html
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 2)) (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->-r requirements.txt (line 1)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->-r requirements.txt (line 1)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->-r requirements.txt (line 1)) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->-r requirements.txt (line 2)) (2.5)
# Collecting html2text
#   Using cached html2text-2024.2.26-py3-none-any.whl
# Installing collected packages: html2text
# Successfully installed html2text-2024.2.26
# Requirement already satisfied: requests-html in /usr/local/lib/python3.10/dist-packages (0.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from requests-html) (2.31.0)
# Requirement already satisfied: pyquery in /usr/local/lib/python3.10/dist-packages (from requests-html) (2.0.0)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.10/dist-packages (from requests-html) (1.4.0)
# Requirement already satisfied: parse in /usr/local/lib/python3.10/dist-packages (from requests-html) (1.20.1)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.10/dist-packages (from requests-html) (0.0.2)
# Requirement already satisfied: w3lib in /usr/local/lib/python3.10/dist-packages (from requests-html) (2.1.2)
# Requirement already satisfied: pyppeteer>=0.0.14 in /usr/local/lib/python3.10/dist-packages (from requests-html) (2.0.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (1.4.4)
# Requirement already satisfied: certifi>=2023 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (2024.2.2)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (7.0.1)
# Requirement already satisfied: pyee<12.0.0,>=11.0.0 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (11.1.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (4.66.2)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (1.26.18)
# Requirement already satisfied: websockets<11.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html) (10.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->requests-html) (4.12.3)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.10/dist-packages (from pyquery->requests-html) (4.9.4)
# Requirement already satisfied: cssselect>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pyquery->requests-html) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->requests-html) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->requests-html) (3.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html) (3.17.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pyee<12.0.0,>=11.0.0->pyppeteer>=0.0.14->requests-html) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->requests-html) (2.5)

# %%
import time

import requests

# %%
url = "https://visitseattle.org/events/page/1"

# Create -> POST
# Read   -> GET
# Update -> PUT
# Delete -> DELETE
#
# requests.post("https://concert.com/buy")
# requests.put("https://github.com/ianchen06")
# requests.delete("https://facebook.com/ianchen06/post/1")

res = requests.get(url)

# %%
# 200 -> OK
# 201 -> Created (after POST)
# 301 -> Moved Permanently
# 302
# 400 -> Bad Request (error from user)
# 404 -> Not Found (error from user)
# 500 -> Internal Server Error (error from server)
res.status_code
# Out:
# 200

# %%
res.text
# Out:
# '<!doctype html>\r\n<html lang="en-US">\r\n<head> <script type="text/javascript">\n/* <![CDATA[ */\n var gform;gform||(document.addEventListener("gform_main_scripts_loaded",function(){gform.scriptsLoaded=!0}),window.addEventListener("DOMContentLoaded",function(){gform.domLoaded=!0}),gform={domLoaded:!1,scriptsLoaded:!1,initializeOnLoaded:function(o){gform.domLoaded&&gform.scriptsLoaded?o():!gform.domLoaded&&gform.scriptsLoaded?window.addEventListener("DOMContentLoaded",o):document.addEventListener("gform_main_scripts_loaded",o)},hooks:{action:{},filter:{}},addAction:function(o,n,r,t){gform.addHook("action",o,n,r,t)},addFilter:function(o,n,r,t){gform.addHook("filter",o,n,r,t)},doAction:function(o){gform.doHook("action",o,arguments)},applyFilters:function(o){return gform.doHook("filter",o,arguments)},removeAction:function(o,n){gform.removeHook("action",o,n)},removeFilter:function(o,n,r){gform.removeHook("filter",o,n,r)},addHook:function(o,n,r,t,i){null==gform.hooks[o][n]&&(gform.hooks[o][n]=[]);var e=gform.hooks[o][n];null==i&&(i=n+"_"+e.length),gform.hooks[o][n].push({tag:i,callable:r,priority:t=null==t?10:t})},doHook:function(n,o,r){var t;if(r=Array.prototype.slice.call(r,1),null!=gform.hooks[n][o]&&((o=gform.hooks[n][o]).sort(function(o,n){return o.priority-n.priority}),o.forEach(function(o){"function"!=typeof(t=o.callable)&&(t=window[t]),"action"==n?t.apply(null,r):r[0]=t.apply(null,r)})),"filter"==n)return r[0]},removeHook:function(o,n,t,i){var r;null!=gform.hooks[o][n]&&(r=(r=gform.hooks[o][n]).filter(function(o,n,r){return!!(null!=i&&i!=o.tag||null!=t&&t!=o.priority)}),gform.hooks[o][n]=r)}}); \n/* ]]> */\n</script>\n\r\n    \r\n    <meta http-equiv="Content-Type"\r\n          content="text/html; charset=UTF-8"/>\r\n    <meta name="viewport" content="width=device-width, initial-scale=1">\r\n    <meta name="application-name" content="Visit Seattle"/>\r\n    <meta name="google-site-verification"\r\n          content="XMxLNYBJpveaQyQsj6qvtweLwfpyvUXwfe9wA186eLg"/>\r\n\r\n    \r\n    <!-- 1/04/2017 -->\r\n<link rel="apple-touch-icon" sizes="180x180" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon.png?v=pgq06ygd45">\r\n<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon-precomposed.png?v=pgq06ygd45">\r\n<link rel="apple-touch-icon-precomposed" sizes="57x57" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon-57x57.png" />\r\n<link rel="apple-touch-icon-precomposed" sizes="114x114" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon-114x114.png" />\r\n<link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon-72x72.png" />\r\n<link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon-144x144.png" />\r\n<link rel="apple-touch-icon-precomposed" sizes="60x60" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon-60x60.png" />\r\n<link rel="apple-touch-icon-precomposed" sizes="120x120" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon-120x120.png" />\r\n<link rel="apple-touch-icon-precomposed" sizes="76x76" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon-76x76.png" />\r\n<link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/apple-touch-icon-152x152.png" />\r\n<link rel="icon" type="image/png" sizes="32x32" href="https://visitseattle.org/wp-content/themes/visitseattle/library/images/favicon/favicon-32x32.png?v=pgq06ygd45">\r\n<link rel="icon" ty ...

# %%
open("seattleevents.html", "w").write(res.text)
# Out:
# 183715

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(res.text, "html.parser")

# %%
selector = "div.search-result-preview > div > h3 > a"

a_eles = soup.select(selector)
a_eles
# Out:
# [<a href="https://visitseattle.org/events/4inecs/" title="4inecs">4inecs </a>,
#  <a href="https://visitseattle.org/events/calidore-quartet-abeo-quartet/" title="Calidore Quartet &amp; Abeo Quartet">Calidore Quartet &amp; Abeo Quartet </a>,
#  <a href="https://visitseattle.org/events/debut/" title="Debut">Debut </a>,
#  <a href="https://visitseattle.org/events/holding-movement/" title="Holding / Movement">Holding / Movement </a>,
#  <a href="https://visitseattle.org/events/international-womens-day-live-sessions-concert/" title="International Women’s Day Live Sessions Concert">International Women’s Day Live Sessions Concert </a>,
#  <a href="https://visitseattle.org/events/josh-wolf/" title="Josh Wolf">Josh Wolf </a>,
#  <a href="https://visitseattle.org/events/karla-bonoff/" title="Karla Bonoff">Karla Bonoff </a>,
#  <a href="https://visitseattle.org/events/palestinian-lana-ikelan-and-israeli-noga-bar-oz/" title="Palestinian Lana Ikelan and Israeli Noga Bar Oz">Palestinian Lana Ikelan and Israeli Noga Bar Oz </a>,
#  <a href="https://visitseattle.org/events/seattle-kraken-vs-winnipeg-jets/" title="Seattle Kraken vs. Winnipeg Jets">Seattle Kraken vs. Winnipeg Jets </a>]

# %%
[x['href'] for x in a_eles]
# Out:
# ['https://visitseattle.org/events/4inecs/',
#  'https://visitseattle.org/events/calidore-quartet-abeo-quartet/',
#  'https://visitseattle.org/events/debut/',
#  'https://visitseattle.org/events/holding-movement/',
#  'https://visitseattle.org/events/international-womens-day-live-sessions-concert/',
#  'https://visitseattle.org/events/josh-wolf/',
#  'https://visitseattle.org/events/karla-bonoff/',
#  'https://visitseattle.org/events/palestinian-lana-ikelan-and-israeli-noga-bar-oz/',
#  'https://visitseattle.org/events/seattle-kraken-vs-winnipeg-jets/']

# %%
import requests
from bs4 import BeautifulSoup

for url in ['https://visitseattle.org/events/kate-alice-marshall/', 'https://visitseattle.org/events/machine-head/', ...]:
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an HTTPError for bad responses
        soup = BeautifulSoup(response.text, 'html.parser')
        # Extract information from the HTML using BeautifulSoup
        # Example: print the title of the page
        title = soup.title.string.strip()
        print(f"Title of {url}: {title}")
    except requests.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
# Out:
# Error fetching data from https://visitseattle.org/events/kate-alice-marshall/: 404 Client Error: Not Found for url: https://visitseattle.org/events/kate-alice-marshall/
# Error fetching data from https://visitseattle.org/events/machine-head/: 404 Client Error: Not Found for url: https://visitseattle.org/events/machine-head/
# Error fetching data from Ellipsis: Invalid URL 'Ellipsis': No scheme supplied. Perhaps you meant https://Ellipsis?

# %%
import requests
from bs4 import BeautifulSoup

def scrape_event_urls(url):
    event_urls = []

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an HTTPError for bad responses
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract event URLs using the provided CSS selector
        selector = "div.search-result-preview > div > h3 > a"
        event_tags = soup.select(selector)
        event_urls.extend([tag['href'] for tag in event_tags])

        return event_urls
    except requests.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return None

# Scraping event URLs from all pages
base_url = "https://visitseattle.org/events/page/"
total_pages = 41  # You mentioned 41 pages
all_event_urls = []

for page_number in range(1, total_pages + 1):
    url = f"{base_url}{page_number}"
    event_urls = scrape_event_urls(url)

    if event_urls:
        all_event_urls.extend(event_urls)

# Print the result
print(all_event_urls)
# Out:
# ['https://visitseattle.org/events/4inecs/', 'https://visitseattle.org/events/calidore-quartet-abeo-quartet/', 'https://visitseattle.org/events/debut/', 'https://visitseattle.org/events/holding-movement/', 'https://visitseattle.org/events/international-womens-day-live-sessions-concert/', 'https://visitseattle.org/events/josh-wolf/', 'https://visitseattle.org/events/karla-bonoff/', 'https://visitseattle.org/events/palestinian-lana-ikelan-and-israeli-noga-bar-oz/', 'https://visitseattle.org/events/seattle-kraken-vs-winnipeg-jets/', 'https://visitseattle.org/events/the-wood-brothers/', 'https://visitseattle.org/events/frye-in-focus-lineajes-frye-salon/', 'https://visitseattle.org/events/xthe-life-and-times-of-malcolm-x/', 'https://visitseattle.org/events/bach-st-john-passion/', 'https://visitseattle.org/events/ariel-pink/', 'https://visitseattle.org/events/biblioteka/', 'https://visitseattle.org/events/carnaval-with-entremundos-big-band/', 'https://visitseattle.org/events/coco-montoya/', 'https://visitseattle.org/events/emily-calandrelli-unleash-your-inner-scientist/', 'https://visitseattle.org/events/helene-grimaud/', 'https://visitseattle.org/events/josiah-and-the-bonnevilles/', 'https://visitseattle.org/events/mahan-esfahan/', 'https://visitseattle.org/events/the-paper-kites/', 'https://visitseattle.org/events/positive-fragmentation/', 'https://visitseattle.org/events/antonio-m-gomez-lineajes/', 'https://visitseattle.org/events/soren-solkaer-sort-sol/', 'https://visitseattle.org/events/luchadora/', 'https://visitseattle.org/events/deseo-carmin/', 'https://visitseattle.org/events/our-place-in-this-world-winter-2024-concert/', 'https://visitseattle.org/events/rhapsody-in-shmaltz/', 'https://visitseattle.org/events/short-stories-live-through-someone-elses-eyes/', 'https://visitseattle.org/events/angie-mcmahon/', 'https://visitseattle.org/events/crosses/', 'https://visitseattle.org/events/dancing-with-the-stars/', 'https://visitseattle.org/events/earshot-golden-ear-awards-party-jun-iida/', 'https://visitseattle.org/events/sasha-lapointe/', 'https://visitseattle.org/events/wild-cats-revealed-national-geographic-live/', 'https://visitseattle.org/events/seattle-kraken-vs-vegas-golden-knights/', 'https://visitseattle.org/events/special-efx-all-stars/', 'https://visitseattle.org/events/tommyinnit/', 'https://visitseattle.org/events/black-uhuru/', 'https://visitseattle.org/events/cat-power/', 'https://visitseattle.org/events/cody-bartels/', 'https://visitseattle.org/events/eyedress/', 'https://visitseattle.org/events/kendra-morris/', 'https://visitseattle.org/events/my-dinner-with-sam/', 'https://visitseattle.org/events/susannah-fox-with-sally-james/', 'https://visitseattle.org/events/tim-berne-trio/', 'https://visitseattle.org/events/cool-company/', 'https://visitseattle.org/events/replay-matinee-roxanne-dunbar-ortiz/', 'https://visitseattle.org/events/seattle-kraken-vs-washington-capitals/', 'https://visitseattle.org/events/taste-washington-pacific-standard/', 'https://visitseattle.org/events/the-lord-of-the-rings-the-return-of-the-king/', 'https://visitseattle.org/events/tricia-romano-voices-of-the-village/', 'https://visitseattle.org/events/veeze/', 'https://visitseattle.org/events/autoheart/', 'https://visitseattle.org/events/benjamin-wurgaft-and-merry-white/', 'https://visitseattle.org/events/drew-martin/', 'https://visitseattle.org/events/goose-vargis/', 'https://visitseattle.org/events/lee-fields-and-monophonics/', 'https://visitseattle.org/events/mitis/', 'https://visitseattle.org/events/shakey/', 'https://visitseattle.org/events/taste-washington-the-new-vintage/', 'https://visitseattle.org/events/taylor-rave/', 'https://visitseattle.org/events/text-me-back-live/', 'https://visitseattle.org/events/the-snuts/', 'https://visitseattle.org/events/tuomo-and-markus-concert/', 'https://visitseattle.org/events/yuri/', 'https://visitseattle.org/events/mark-morris-dance-group-the-look-of-love/', 'https://visitseattle.org/events/sibelius-n ...

# %%
import requests
from bs4 import BeautifulSoup
import csv

def extract_event_details(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an HTTPError for bad responses
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract information from the HTML using BeautifulSoup
        name = soup.find('h1', class_='page-title').text.strip()
        date = soup.find("h4").find_all("span")[0].text.strip()
        location = soup.find("h4").find_all("span")[1].text.strip()
        event_type = soup.find_all("a", class_="button big medium black category")[0].text.strip()
        region = soup.find_all("a", class_="button big medium black category")[1].text.strip()

        # Store the details in a dictionary
        event_details = {
            'Name': name,
            'Date': date,
            'Location': location,
            'Type': event_type,
            'Region': region
        }

        print(f"Details for {name} ({url}):")
        print(f"  Date: {date}")
        print(f"  Location: {location}")
        print(f"  Type: {event_type}")
        print(f"  Region: {region}")
        print()

        return event_details

    except requests.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return None

# List of event URLs


all_event_details = []

# Extract details for each event URL
for url in all_event_urls:
    event_details = extract_event_details(url)
    if event_details:
        all_event_details.append(event_details)

# Store the details in a CSV file
csv_file_path = 'events.csv'
fields = ['Name', 'Date', 'Location', 'Type', 'Region']

with open(csv_file_path, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fields)
    # Write the header
    writer.writeheader()
    # Write the event details
    writer.writerows(all_event_details)

print(f"Event details stored in {csv_file_path}")
# Out:
# Details for 4inecs (https://visitseattle.org/events/4inecs/):
#   Date: 3/8/2024
#   Location: Funhouse
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Calidore Quartet & Abeo Quartet (https://visitseattle.org/events/calidore-quartet-abeo-quartet/):
#   Date: 3/8/2024
#   Location: 415 Westlake
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Debut (https://visitseattle.org/events/debut/):
#   Date: 3/8/2024
#   Location: Barboza
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Holding / Movement (https://visitseattle.org/events/holding-movement/):
#   Date: 3/8/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for International Women’s Day Live Sessions Concert (https://visitseattle.org/events/international-womens-day-live-sessions-concert/):
#   Date: 3/8/2024
#   Location: The Royal Room
#   Type: Music
#   Region: South Seattle
#
# Details for Josh Wolf (https://visitseattle.org/events/josh-wolf/):
#   Date: 3/8/2024
#   Location: The Neptune Theatre
#   Type: Theatre
#   Region: University District
#
# Details for Karla Bonoff (https://visitseattle.org/events/karla-bonoff/):
#   Date: 3/8/2024
#   Location: The Triple Door
#   Type: Music
#   Region: Downtown
#
# Details for Palestinian Lana Ikelan and Israeli Noga Bar Oz (https://visitseattle.org/events/palestinian-lana-ikelan-and-israeli-noga-bar-oz/):
#   Date: 3/8/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Seattle Kraken vs. Winnipeg Jets (https://visitseattle.org/events/seattle-kraken-vs-winnipeg-jets/):
#   Date: 3/8/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for The Wood Brothers (https://visitseattle.org/events/the-wood-brothers/):
#   Date: 3/8/2024
#   Location: The Moore Theatre
#   Type: Music
#   Region: Downtown
#
# Details for Frye in Focus: LINEAJES + Frye Salon (https://visitseattle.org/events/frye-in-focus-lineajes-frye-salon/):
#   Date: Now through 3/9/2024
#   Location: Frye Art Museum
#   Type: Museums
#   Region: Capitol Hill / Central District
#
# Details for X:The Life and Times of Malcolm X (https://visitseattle.org/events/xthe-life-and-times-of-malcolm-x/):
#   Date: Now through 3/9/2024
#   Location: Marion Oliver McCaw Hall
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Bach St. John Passion (https://visitseattle.org/events/bach-st-john-passion/):
#   Date: Now through 3/9/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Ariel Pink (https://visitseattle.org/events/ariel-pink/):
#   Date: 3/9/2024
#   Location: El Corazon
#   Type: Music
#   Region: Downtown
#
# Details for Biblioteka (https://visitseattle.org/events/biblioteka/):
#   Date: 3/9/2024
#   Location: Sunset Tavern
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Carnaval with EntreMundos Big Band (https://visitseattle.org/events/carnaval-with-entremundos-big-band/):
#   Date: 3/9/2024
#   Location: The Royal Room
#   Type: Music
#   Region: South Seattle
#
# Details for Coco Montoya (https://visitseattle.org/events/coco-montoya/):
#   Date: 3/9/2024
#   Location: The Triple Door
#   Type: Music
#   Region: Downtown
#
# Details for Emily Calandrelli: Unleash Your Inner Scientist (https://visitseattle.org/events/emily-calandrelli-unleash-your-inner-scientist/):
#   Date: 3/9/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Helene Grimaud (https://visitseattle.org/events/helene-grimaud/):
#   Date: 3/9/2024
#   Location: Meany Center for the Performing Arts
#   Type: Music
#   Region: University District
#
# Details for Josiah and the Bonnevilles (https://visitseattle.org/events/josiah-and-the-bonnevilles/):
#   Date: 3/9/2024
#   Location: Barboza
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Mahan Esfahan (https://visitseattle.org/events/mahan-esfahan/):
#   Date: 3/9/2024
#   Location: Town Hall Seattle
#   Type: Music
#   Region: Downtown
#
# Details for The Paper Kites (https://visitseattle.org/events/the-paper-kites/):
#   Date: 3/9/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for Positive Fragmentation (https://visitseattle.org/events/positive-fragmentation/):
#   Date: Now through 3/10/2024
#   Location: Bellevue Arts Museum
#   Type: Museums
#   Region: Bellevue / Eastside
#
# Details for Antonio M. Gomez: LINEAJES (https://visitseattle.org/events/antonio-m-gomez-lineajes/):
#   Date: Now through 3/10/2024
#   Location: Frye Art Museum
#   Type: Museums
#   Region: Capitol Hill / Central District
#
# Details for Soren Solkaer: Sort Sol (https://visitseattle.org/events/soren-solkaer-sort-sol/):
#   Date: Now through 3/10/2024
#   Location: National Nordic Museum
#   Type: Museums
#   Region: Fremont / Ballard
#
# Details for Luchadora! (https://visitseattle.org/events/luchadora/):
#   Date: Now through 3/10/2024
#   Location: Seattle Children's Theatre
#   Type: Theatre
#   Region: Queen Anne / Seattle Center
#
# Details for Deseo Carmin (https://visitseattle.org/events/deseo-carmin/):
#   Date: 3/10/2024
#   Location: Sea Monster Lounge
#   Type: Music
#   Region: Wallingford / Greenlake
#
# Details for Our Place in this World: Winter 2024 Concert (https://visitseattle.org/events/our-place-in-this-world-winter-2024-concert/):
#   Date: 3/10/2024
#   Location: Town Hall Seattle
#   Type: Music
#   Region: Downtown
#
# Details for Rhapsody in Shmaltz (https://visitseattle.org/events/rhapsody-in-shmaltz/):
#   Date: 3/10/2024
#   Location: The Royal Room
#   Type: Music
#   Region: South Seattle
#
# Details for Short Stories Live: Through Someone Else’s Eyes (https://visitseattle.org/events/short-stories-live-through-someone-elses-eyes/):
#   Date: 3/10/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Angie McMahon (https://visitseattle.org/events/angie-mcmahon/):
#   Date: 3/11/2024
#   Location: The Crocodile
#   Type: Music
#   Region: Downtown
#
# Details for Crosses (https://visitseattle.org/events/crosses/):
#   Date: 3/11/2024
#   Location: The Moore Theatre
#   Type: Music
#   Region: Downtown
#
# Details for Dancing With The Stars (https://visitseattle.org/events/dancing-with-the-stars/):
#   Date: 3/11/2024
#   Location: The Paramount Theatre
#   Type: Dance
#   Region: Downtown
#
# Details for Earshot Golden Ear Awards Party: Jun Iida (https://visitseattle.org/events/earshot-golden-ear-awards-party-jun-iida/):
#   Date: 3/11/2024
#   Location: The Royal Room
#   Type: Music
#   Region: South Seattle
#
# Details for Sasha LaPointe (https://visitseattle.org/events/sasha-lapointe/):
#   Date: 3/11/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Wild Cats Revealed | National Geographic Live (https://visitseattle.org/events/wild-cats-revealed-national-geographic-live/):
#   Date: 3/10/2024 through 3/12/2024
#   Location: Benaroya Hall
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Seattle Kraken vs. Vegas Golden Knights (https://visitseattle.org/events/seattle-kraken-vs-vegas-golden-knights/):
#   Date: 3/12/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Special EFX All Stars (https://visitseattle.org/events/special-efx-all-stars/):
#   Date: 3/12/2024
#   Location: The Triple Door
#   Type: Music
#   Region: Downtown
#
# Details for TommyInnit (https://visitseattle.org/events/tommyinnit/):
#   Date: 3/12/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for Black Uhuru (https://visitseattle.org/events/black-uhuru/):
#   Date: 3/13/2024
#   Location: Nectar Lounge
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Cat Power (https://visitseattle.org/events/cat-power/):
#   Date: 3/13/2024
#   Location: The Moore Theatre
#   Type: Music
#   Region: Downtown
#
# Details for Cody Bartels (https://visitseattle.org/events/cody-bartels/):
#   Date: 3/13/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Eyedress (https://visitseattle.org/events/eyedress/):
#   Date: 3/13/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Kendra Morris (https://visitseattle.org/events/kendra-morris/):
#   Date: 3/13/2024
#   Location: Sunset Tavern
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for My Dinner with SAM (https://visitseattle.org/events/my-dinner-with-sam/):
#   Date: 3/13/2024
#   Location: Seattle Art Museum
#   Type: Museums
#   Region: Downtown
#
# Details for Susannah Fox with Sally James (https://visitseattle.org/events/susannah-fox-with-sally-james/):
#   Date: 3/13/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Tim Berne Trio (https://visitseattle.org/events/tim-berne-trio/):
#   Date: 3/13/2024
#   Location: The Royal Room
#   Type: Music
#   Region: South Seattle
#
# Details for Cool Company (https://visitseattle.org/events/cool-company/):
#   Date: 3/14/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Replay Matinee: Roxanne Dunbar-Ortiz (https://visitseattle.org/events/replay-matinee-roxanne-dunbar-ortiz/):
#   Date: 3/14/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Seattle Kraken vs. Washington Capitals (https://visitseattle.org/events/seattle-kraken-vs-washington-capitals/):
#   Date: 3/14/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Taste Washington: Pacific Standard (https://visitseattle.org/events/taste-washington-pacific-standard/):
#   Date: 3/14/2024
#   Location: Pier 62
#   Type: Festivals & Special Events
#   Region: Downtown
#
# Details for The Lord of the Rings, The Return of the King (https://visitseattle.org/events/the-lord-of-the-rings-the-return-of-the-king/):
#   Date: 3/14/2024
#   Location: National Nordic Museum
#   Type: Museums
#   Region: Fremont / Ballard
#
# Details for Tricia Romano: Voices of the Village (https://visitseattle.org/events/tricia-romano-voices-of-the-village/):
#   Date: 3/14/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Veeze (https://visitseattle.org/events/veeze/):
#   Date: 3/14/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for Autoheart (https://visitseattle.org/events/autoheart/):
#   Date: 3/15/2024
#   Location: El Corazon
#   Type: Music
#   Region: Downtown
#
# Details for Benjamin Wurgaft and Merry White (https://visitseattle.org/events/benjamin-wurgaft-and-merry-white/):
#   Date: 3/15/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Drew Martin (https://visitseattle.org/events/drew-martin/):
#   Date: 3/15/2024
#   Location: Sunset Tavern
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Goose Vargis (https://visitseattle.org/events/goose-vargis/):
#   Date: 3/15/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Lee Fields and Monophonics (https://visitseattle.org/events/lee-fields-and-monophonics/):
#   Date: 3/15/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for MitiS (https://visitseattle.org/events/mitis/):
#   Date: 3/15/2024
#   Location: Showbox SoDo
#   Type: Music
#   Region: Pioneer Square
#
# Details for Shakey (https://visitseattle.org/events/shakey/):
#   Date: 3/15/2024
#   Location: Slim's Last Chance
#   Type: Music
#   Region: South Seattle
#
# Details for Taste Washington: The New Vintage (https://visitseattle.org/events/taste-washington-the-new-vintage/):
#   Date: 3/15/2024
#   Location: Pier 62
#   Type: Festivals & Special Events
#   Region: Downtown
#
# Details for Taylor Rave (https://visitseattle.org/events/taylor-rave/):
#   Date: 3/15/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Text Me Back Live (https://visitseattle.org/events/text-me-back-live/):
#   Date: 3/15/2024
#   Location: Town Hall Seattle
#   Type: Theatre
#   Region: Downtown
#
# Details for The Snuts (https://visitseattle.org/events/the-snuts/):
#   Date: 3/15/2024
#   Location: Barboza
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Tuomo and Markus Concert (https://visitseattle.org/events/tuomo-and-markus-concert/):
#   Date: 3/15/2024
#   Location: National Nordic Museum
#   Type: Museums
#   Region: Fremont / Ballard
#
# Details for Yuri (https://visitseattle.org/events/yuri/):
#   Date: 3/15/2024
#   Location: The Moore Theatre
#   Type: Music
#   Region: Downtown
#
# Details for Mark Morris Dance Group: The Look of Love (https://visitseattle.org/events/mark-morris-dance-group-the-look-of-love/):
#   Date: 3/14/2024 through 3/16/2024
#   Location: Meany Center for the Performing Arts
#   Type: Music
#   Region: University District
#
# Details for Sibelius & Nielsen (https://visitseattle.org/events/sibelius-nielsen/):
#   Date: 3/14/2024 through 3/16/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Alvin Ailey American Dance Theater (https://visitseattle.org/events/alvin-ailey-american-dance-theater/):
#   Date: 3/15/2024 through 3/16/2024
#   Location: The Paramount Theatre
#   Type: Dance
#   Region: Downtown
#
# Details for Tacoma Stars vs. Chihuahua Savage (https://visitseattle.org/events/tacoma-stars-vs-chihuahua-savage/):
#   Date: 3/15/2024 through 3/16/2024
#   Location: accesso ShoWare Center
#   Type: Sports
#   Region: South
#
# Details for Brian Posehn (https://visitseattle.org/events/brian-posehn/):
#   Date: 3/16/2024
#   Location: The Neptune Theatre
#   Type: Theatre
#   Region: University District
#
# Details for Heroes (https://visitseattle.org/events/heroes/):
#   Date: 3/16/2024
#   Location: Town Hall Seattle
#   Type: Music
#   Region: Downtown
#
# Details for I Sing the Salmon Home (https://visitseattle.org/events/i-sing-the-salmon-home/):
#   Date: 3/16/2024
#   Location: Town Hall Seattle
#   Type: Music
#   Region: Downtown
#
# Details for Matt Hansen (https://visitseattle.org/events/matt-hansen/):
#   Date: 3/16/2024
#   Location: Barboza
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Oneus (https://visitseattle.org/events/oneus/):
#   Date: 3/16/2024
#   Location: The Moore Theatre
#   Type: Music
#   Region: Downtown
#
# Details for Ricky Montgomery (https://visitseattle.org/events/ricky-montgomery/):
#   Date: 3/16/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Seattle Kraken vs. Nashville Predators (https://visitseattle.org/events/seattle-kraken-vs-nashville-predators/):
#   Date: 3/16/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Sounders FC vs. Colorado Rapids (https://visitseattle.org/events/seattle-sounders-fc-vs-colorado-rapids/):
#   Date: 3/16/2024
#   Location: Lumen Field
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Taste Washington: The Seminars (https://visitseattle.org/events/taste-washington-the-seminars/):
#   Date: 3/16/2024
#   Location: Seattle, WA
#   Type: Festivals & Special Events
#   Region: Downtown
#
# Details for Warren Zeiders (https://visitseattle.org/events/warren-zeiders/):
#   Date: 3/16/2024
#   Location: Showbox SoDo
#   Type: Music
#   Region: Pioneer Square
#
# Details for Native Portraiture: Power and Perception (https://visitseattle.org/events/native-portraiture-power-and-perception/):
#   Date: Now through 3/17/2024
#   Location: Tacoma Art Museum
#   Type: Museums
#   Region: South
#
# Details for Places to Call Home: Settlements in the West (https://visitseattle.org/events/places-to-call-home-settlements-in-the-west/):
#   Date: Now through 3/17/2024
#   Location: Tacoma Art Museum
#   Type: Museums
#   Region: South
#
# Details for Nobody Lives Here (https://visitseattle.org/events/nobody-lives-here/):
#   Date: Now through 3/17/2024
#   Location: Wing Luke Museum
#   Type: Museums
#   Region: International District
#
# Details for Seattle Jewish Film Festival (https://visitseattle.org/events/seattle-jewish-film-festival/):
#   Date: Now through 3/17/2024
#   Location: Seattle, WA
#   Type: Festivals & Special Events
#   Region: Downtown
#
# Details for Rootabaga Country (https://visitseattle.org/events/rootabaga-country/):
#   Date: Now through 3/17/2024
#   Location: Opera Center
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Judith Hill – Letters from A Black Widow Tour (https://visitseattle.org/events/judith-hill-letters-from-a-black-widow-tour/):
#   Date: 3/14/2024 through 3/17/2024
#   Location: Dimitriou's Jazz Alley
#   Type: Music
#   Region: Downtown
#
# Details for Festal: Irish Festival Seattle (https://visitseattle.org/events/festal-irish-festival-seattle/):
#   Date: 3/16/2024 through 3/17/2024
#   Location: Seattle Center
#   Type: Festivals & Special Events
#   Region: Queen Anne / Seattle Center
#
# Details for Taste Washington: The Grand Tasting (https://visitseattle.org/events/taste-washington-the-grand-tasting/):
#   Date: 3/16/2024 through 3/17/2024
#   Location: Lumen Field
#   Type: Festivals & Special Events
#   Region: Pioneer Square
#
# Details for BAS (https://visitseattle.org/events/bas/):
#   Date: 3/17/2024
#   Location: Neumos
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Brad Parsons (https://visitseattle.org/events/brad-parsons/):
#   Date: 3/17/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Journeys (https://visitseattle.org/events/journeys/):
#   Date: 3/17/2024
#   Location: Town Hall Seattle
#   Type: Music
#   Region: Downtown
#
# Details for Lunasa (https://visitseattle.org/events/lunasa/):
#   Date: 3/17/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for Rylan Fischer (https://visitseattle.org/events/rylan-fischer/):
#   Date: 3/17/2024
#   Location: Sunset Tavern
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Umphrey’s McGee (https://visitseattle.org/events/umphreys-mcgee/):
#   Date: 3/17/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for ’68 (https://visitseattle.org/events/68/):
#   Date: 3/18/2024
#   Location: Funhouse
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Clarence Moriwaki (https://visitseattle.org/events/clarence-moriwaki/):
#   Date: 3/18/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Jimmy Chamberlin Complex (https://visitseattle.org/events/jimmy-chamberlin-complex/):
#   Date: 3/18/2024
#   Location: Neumos
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Seattle Kraken vs. Buffalo Sabres (https://visitseattle.org/events/seattle-kraken-vs-buffalo-sabres/):
#   Date: 3/18/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Taste Washington: No Frills (https://visitseattle.org/events/taste-washington-no-frills/):
#   Date: 3/18/2024
#   Location: Seattle, WA
#   Type: Festivals & Special Events
#   Region: Downtown
#
# Details for Briston Maroney: Ultrapure Tour (https://visitseattle.org/events/briston-maroney-ultrapure-tour/):
#   Date: 3/18/2024 through 3/19/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for Ana Tijoux (https://visitseattle.org/events/ana-tijoux/):
#   Date: 3/19/2024
#   Location: The Crocodile
#   Type: Music
#   Region: Downtown
#
# Details for Brad Gooch: The Life and Line of Keith Haring (https://visitseattle.org/events/brad-gooch-the-life-and-line-of-keith-haring/):
#   Date: 3/19/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Darkest Hour (https://visitseattle.org/events/darkest-hour/):
#   Date: 3/19/2024
#   Location: El Corazon
#   Type: Music
#   Region: Downtown
#
# Details for Dragontail Peak (https://visitseattle.org/events/dragontail-peak/):
#   Date: 3/19/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for El Perro del Mar (https://visitseattle.org/events/el-perro-del-mar/):
#   Date: 3/19/2024
#   Location: Barboza
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Letterkenny (https://visitseattle.org/events/letterkenny/):
#   Date: 3/19/2024
#   Location: Showbox SoDo
#   Type: Theatre
#   Region: Pioneer Square
#
# Details for Richard Lui and Dr. Kate Zhong: Caring for the Caregiver (https://visitseattle.org/events/richard-lui-and-dr-kate-zhong-caring-for-the-caregiver/):
#   Date: 3/19/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for True Loves (https://visitseattle.org/events/true-loves/):
#   Date: 3/19/2024
#   Location: Dimitriou's Jazz Alley
#   Type: Music
#   Region: Downtown
#
# Details for Combichrist (https://visitseattle.org/events/combichrist/):
#   Date: 3/20/2024
#   Location: El Corazon
#   Type: Music
#   Region: Downtown
#
# Details for Jon Vinyl (https://visitseattle.org/events/jon-vinyl/):
#   Date: 3/20/2024
#   Location: Barboza
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Mania the ABBA Tribute (https://visitseattle.org/events/mania-the-abba-tribute/):
#   Date: 3/20/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for Mayuan Poet (https://visitseattle.org/events/mayuan-poet/):
#   Date: 3/20/2024
#   Location: Neumos
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for The Forensic Archive of Landscapes: Paloma Contreras Lomas (https://visitseattle.org/events/the-forensic-archive-of-landscapes-paloma-contreras-lomas/):
#   Date: 3/20/2024
#   Location: Seattle Art Museum
#   Type: Museums
#   Region: Downtown
#
# Details for Flyana Boss (https://visitseattle.org/events/flyana-boss/):
#   Date: 3/21/2024
#   Location: Barboza
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for glass beach (https://visitseattle.org/events/glass-beach/):
#   Date: 3/21/2024
#   Location: Neumos
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Ignite #45 (https://visitseattle.org/events/ignite-45/):
#   Date: 3/21/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Lee McIntyre: A History of Disinformation (https://visitseattle.org/events/lee-mcintyre-a-history-of-disinformation/):
#   Date: 3/21/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Barely Alive (https://visitseattle.org/events/barely-alive/):
#   Date: 3/22/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Dadi Freyr (https://visitseattle.org/events/dadi-freyr/):
#   Date: 3/22/2024
#   Location: Showbox SoDo
#   Type: Music
#   Region: Pioneer Square
#
# Details for Los Huracanes del Norte: A Otro Nivel Tour 2024 (https://visitseattle.org/events/los-huracanes-del-norte-a-otro-nivel-tour-2024/):
#   Date: 3/22/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for More Music (https://visitseattle.org/events/more-music/):
#   Date: 3/22/2024
#   Location: The Moore Theatre
#   Type: Music
#   Region: Downtown
#
# Details for The Moth Seattle GrandSLAM (https://visitseattle.org/events/the-moth-seattle-grandslam/):
#   Date: 3/22/2024
#   Location: Town Hall Seattle
#   Type: Festivals & Special Events
#   Region: Downtown
#
# Details for Taste Washington: Dinner Series (https://visitseattle.org/events/taste-washington-dinner-series/):
#   Date: 3/21/2024 through 3/23/2024
#   Location: Seattle, WA
#   Type: Festivals & Special Events
#   Region: Downtown
#
# Details for Alkaline Trio (https://visitseattle.org/events/alkaline-trio/):
#   Date: 3/23/2024
#   Location: Showbox SoDo
#   Type: Music
#   Region: Pioneer Square
#
# Details for An Encomium for Doug Crutchfield (https://visitseattle.org/events/an-encomium-for-doug-crutchfield/):
#   Date: 3/23/2024
#   Location: National Nordic Museum
#   Type: Museums
#   Region: Fremont / Ballard
#
# Details for Jennifer Hartswick Band (https://visitseattle.org/events/jennifer-hartswick-band/):
#   Date: 3/23/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Monster Energy AMA Supercross! (https://visitseattle.org/events/monster-energy-ama-supercross/):
#   Date: 3/23/2024
#   Location: Lumen Field
#   Type: Festivals & Special Events
#   Region: Pioneer Square
#
# Details for Saturday Family Concert: Neon Brass Party (https://visitseattle.org/events/saturday-family-concert-neon-brass-party/):
#   Date: 3/23/2024
#   Location: Town Hall Seattle
#   Type: Music
#   Region: Downtown
#
# Details for Tacoma Stars vs. Empire Strykers (https://visitseattle.org/events/tacoma-stars-vs-empire-strykers/):
#   Date: 3/23/2024
#   Location: accesso ShoWare Center
#   Type: Sports
#   Region: South
#
# Details for Something’s Afoot (https://visitseattle.org/events/somethings-afoot/):
#   Date: Now through 3/24/2024
#   Location: The 5th Avenue Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for One Thousand Pieces (https://visitseattle.org/events/one-thousand-pieces/):
#   Date: 3/15/2024 through 3/24/2024
#   Location: Marion Oliver McCaw Hall
#   Type: Dance
#   Region: Queen Anne / Seattle Center
#
# Details for Marcus Miller (https://visitseattle.org/events/marcus-miller/):
#   Date: 3/21/2024 through 3/24/2024
#   Location: Dimitriou's Jazz Alley
#   Type: Music
#   Region: Downtown
#
# Details for Simon Trpceski Plays Tchaikovsky (https://visitseattle.org/events/simon-trpceski-plays-tchaikovsky/):
#   Date: 3/21/2024 through 3/24/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Blank Canvas (https://visitseattle.org/events/blank-canvas/):
#   Date: 3/24/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Celebrate Holi! Spring Festival of Colors from South Asia (https://visitseattle.org/events/celebrate-holi-spring-festival-of-colors-from-south-asia/):
#   Date: 3/24/2024
#   Location: Burke Museum
#   Type: Museums
#   Region: University District
#
# Details for Destin Conrad (https://visitseattle.org/events/destin-conrad/):
#   Date: 3/24/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for Festal: Seattle’s French Fest (https://visitseattle.org/events/festal-seattles-french-fest/):
#   Date: 3/24/2024
#   Location: Seattle Center
#   Type: Festivals & Special Events
#   Region: Queen Anne / Seattle Center
#
# Details for Kathy Ross: Serious Fun (https://visitseattle.org/events/kathy-ross-serious-fun/):
#   Date: 3/24/2024
#   Location: Bainbridge Island Museum of Art
#   Type: Museums
#   Region: West
#
# Details for Seattle Kraken vs. Montreal Canadiens (https://visitseattle.org/events/seattle-kraken-vs-montreal-canadiens/):
#   Date: 3/24/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Shain Shapiro with Greg Scruggs: How Music Builds Cities (https://visitseattle.org/events/shain-shapiro-with-greg-scruggs-how-music-builds-cities/):
#   Date: 3/24/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Zakir Khan Live (https://visitseattle.org/events/zakir-khan-live/):
#   Date: 3/24/2024
#   Location: The Moore Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for Ann Annie (https://visitseattle.org/events/ann-annie/):
#   Date: 3/25/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Chelsea Wolfe (https://visitseattle.org/events/chelsea-wolfe/):
#   Date: 3/25/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for Jonah Kagen (https://visitseattle.org/events/jonah-kagen/):
#   Date: 3/25/2024
#   Location: Barboza
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Juliet Hooker with Megan Ming Francis: The Politics of Loss (https://visitseattle.org/events/juliet-hooker-with-megan-ming-francis-the-politics-of-loss/):
#   Date: 3/25/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Kim Dracula (https://visitseattle.org/events/kim-dracula/):
#   Date: 3/25/2024
#   Location: Neumos
#   Type: Music
#   Region: Capitol Hill / Central District
#
# Details for Sasha Issenberg with Austin Jenkins: The Lie Detectives (https://visitseattle.org/events/sasha-issenberg-with-austin-jenkins-the-lie-detectives/):
#   Date: 3/25/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Tea Obreht (https://visitseattle.org/events/tea-obreht/):
#   Date: 3/25/2024
#   Location: Elliott Bay Book Company
#   Type: Readings & Lectures
#   Region: Capitol Hill / Central District
#
# Details for Lifecycle of Seattle Artists (https://visitseattle.org/events/lifecycle-of-seattle-artists/):
#   Date: 3/26/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Seattle Kraken vs. Anaheim Ducks (https://visitseattle.org/events/seattle-kraken-vs-anaheim-ducks/):
#   Date: 3/26/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Omar Sosa Quarteto Americanos (https://visitseattle.org/events/omar-sosa-quarteto-americanos/):
#   Date: 3/26/2024 through 3/27/2024
#   Location: Dimitriou's Jazz Alley
#   Type: Music
#   Region: Downtown
#
# Details for Caetano Veloso (https://visitseattle.org/events/caetano-veloso/):
#   Date: 3/27/2024
#   Location: The Moore Theatre
#   Type: Music
#   Region: Downtown
#
# Details for Jazz Underground (https://visitseattle.org/events/jazz-underground/):
#   Date: 3/27/2024
#   Location: The Royal Room
#   Type: Music
#   Region: South Seattle
#
# Details for Paris Shadows (https://visitseattle.org/events/paris-shadows/):
#   Date: 3/27/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Andre Nikatina (https://visitseattle.org/events/andre-nikatina/):
#   Date: 3/28/2024
#   Location: Nectar Lounge
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for DakhaBrakha (https://visitseattle.org/events/dakhabrakha/):
#   Date: 3/28/2024
#   Location: The Moore Theatre
#   Type: Music
#   Region: Downtown
#
# Details for Foo Gazzi (https://visitseattle.org/events/foo-gazzi/):
#   Date: 3/28/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Health (https://visitseattle.org/events/health/):
#   Date: 3/28/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Ladysmith Black Mambazo (https://visitseattle.org/events/ladysmith-black-mambazo/):
#   Date: 3/28/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for Matthew Desmond: Poverty, By America (https://visitseattle.org/events/matthew-desmond-poverty-by-america/):
#   Date: 3/28/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Seattle Kraken vs. Anaheim Ducks (https://visitseattle.org/events/seattle-kraken-vs-anaheim-ducks-2/):
#   Date: 3/28/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Andy Coe Band (https://visitseattle.org/events/andy-coe-band/):
#   Date: 3/29/2024
#   Location: Nectar Lounge
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for DJ DAN with Max Gain (https://visitseattle.org/events/dj-dan-with-max-gain/):
#   Date: 3/29/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for God’s Child (https://visitseattle.org/events/gods-child/):
#   Date: 3/29/2024
#   Location: The Neptune Theatre
#   Type: Theatre
#   Region: University District
#
# Details for Hamdi (https://visitseattle.org/events/hamdi/):
#   Date: 3/29/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Live Wire with Luke Burbank (https://visitseattle.org/events/live-wire-with-luke-burbank/):
#   Date: 3/29/2024
#   Location: Town Hall Seattle
#   Type: Theatre
#   Region: Downtown
#
# Details for Loud Luxury (https://visitseattle.org/events/loud-luxury/):
#   Date: 3/29/2024
#   Location: Showbox SoDo
#   Type: Music
#   Region: Pioneer Square
#
# Details for SAM Remix (https://visitseattle.org/events/sam-remix/):
#   Date: 3/29/2024
#   Location: Seattle Art Museum
#   Type: Museums
#   Region: Downtown
#
# Details for Tim McGraw (https://visitseattle.org/events/tim-mcgraw/):
#   Date: 3/29/2024
#   Location: Climate Pledge Arena
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Fragments of the Sea II (https://visitseattle.org/events/fragments-of-the-sea-ii/):
#   Date: Now through 3/30/2024
#   Location: Gallery 110
#   Type: Visual Arts & Galleries
#   Region: Pioneer Square
#
# Details for Harold and the Purple Crayon (https://visitseattle.org/events/harold-and-the-purple-crayon/):
#   Date: 3/23/2024 through 3/30/2024
#   Location: Marion Oliver McCaw Hall
#   Type: Dance
#   Region: Queen Anne / Seattle Center
#
# Details for Cowboy Disco (https://visitseattle.org/events/cowboy-disco/):
#   Date: 3/30/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Danny Brown (https://visitseattle.org/events/danny-brown/):
#   Date: 3/30/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Dr. Jane Goodall (https://visitseattle.org/events/dr-jane-goodall/):
#   Date: 3/30/2024
#   Location: The Moore Theatre
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Michael Blaustein (https://visitseattle.org/events/michael-blaustein/):
#   Date: 3/30/2024
#   Location: The Neptune Theatre
#   Type: Theatre
#   Region: University District
#
# Details for Monster Jam (https://visitseattle.org/events/monster-jam/):
#   Date: 3/30/2024
#   Location: Lumen Field
#   Type: Festivals & Special Events
#   Region: Pioneer Square
#
# Details for Seattle Kraken vs. Dallas Stars (https://visitseattle.org/events/seattle-kraken-vs-dallas-stars/):
#   Date: 3/30/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Timmy Trumpet’s Freakshow (https://visitseattle.org/events/timmy-trumpets-freakshow/):
#   Date: 3/30/2024
#   Location: Showbox SoDo
#   Type: Music
#   Region: Pioneer Square
#
# Details for Illuminate: Glass Art for Early Learners (https://visitseattle.org/events/illuminate-glass-art-for-early-learners/):
#   Date: Now through 3/31/2024
#   Location: Museum of Glass
#   Type: Museums
#   Region: South
#
# Details for Al Young’s 1970 Dodge Challenger Drag Racer (https://visitseattle.org/events/al-youngs-1970-dodge-challenger-drag-racer/):
#   Date: Now through 3/31/2024
#   Location: Museum of History & Industry
#   Type: Museums
#   Region: Queen Anne / Seattle Center
#
# Details for Shine On Seattle (https://visitseattle.org/events/shine-on-seattle/):
#   Date: Now through 3/31/2024
#   Location: Pioneer Square
#   Type: Festivals & Special Events
#   Region: Pioneer Square
#
# Details for Exhibition Tour: Calder (https://visitseattle.org/events/exhibition-tour-calder/):
#   Date: Now through 3/31/2024
#   Location: Seattle Art Museum
#   Type: Museums
#   Region: Downtown
#
# Details for Public Tour: Highlights from SAM’s Collection (https://visitseattle.org/events/public-tour-highlights-from-sams-collection/):
#   Date: Now through 3/31/2024
#   Location: Seattle Art Museum
#   Type: Museums
#   Region: Downtown
#
# Details for Public Tour: Journeys Through Time and Space (https://visitseattle.org/events/public-tour-journeys-through-time-and-space/):
#   Date: Now through 3/31/2024
#   Location: Seattle Asian Art Museum
#   Type: Museums
#   Region: Capitol Hill / Central District
#
# Details for Sanctuary City (https://visitseattle.org/events/sanctuary-city/):
#   Date: Now through 3/31/2024
#   Location: Seattle Rep
#   Type: Theatre
#   Region: Queen Anne / Seattle Center
#
# Details for Stew (https://visitseattle.org/events/stew/):
#   Date: 3/15/2024 through 3/31/2024
#   Location: ACT Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for Seattle Mariners vs. Boston Red Sox (https://visitseattle.org/events/seattle-mariners-vs-boston-red-sox/):
#   Date: 3/28/2024 through 3/31/2024
#   Location: T-Mobile Park
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Sakura-Con 2024 (https://visitseattle.org/events/sakura-con-2024/):
#   Date: 3/29/2024 through 3/31/2024
#   Location: Seattle Convention Center
#   Type: Festivals & Special Events
#   Region: Downtown
#
# Details for Queensryche and Armored Saint (https://visitseattle.org/events/queensryche-and-armored-saint/):
#   Date: 3/31/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for Noize MC (https://visitseattle.org/events/noize-mc/):
#   Date: 4/1/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Jimbo’s Drag Circus (https://visitseattle.org/events/jimbos-drag-circus/):
#   Date: 4/2/2024
#   Location: The Neptune Theatre
#   Type: Theatre
#   Region: University District
#
# Details for Joey Harkum (https://visitseattle.org/events/joey-harkum/):
#   Date: 4/2/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for MT Connolly (https://visitseattle.org/events/mt-connolly/):
#   Date: 4/2/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for The 350’s (https://visitseattle.org/events/the-350s/):
#   Date: 4/2/2024
#   Location: Sea Monster Lounge
#   Type: Music
#   Region: Wallingford / Greenlake
#
# Details for Seattle Mariners vs. Cleveland Guardians (https://visitseattle.org/events/seattle-mariners-vs-cleveland-guardians/):
#   Date: 4/1/2024 through 4/3/2024
#   Location: T-Mobile Park
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Jake Shimabukuro (https://visitseattle.org/events/jake-shimabukuro/):
#   Date: 4/2/2024 through 4/3/2024
#   Location: Dimitriou's Jazz Alley
#   Type: Music
#   Region: Downtown
#
# Details for Sleater-Kinney (https://visitseattle.org/events/sleater-kinney/):
#   Date: 4/2/2024 through 4/3/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Becky Selengut: Misunderstood Vegetables (https://visitseattle.org/events/becky-selengut-misunderstood-vegetables/):
#   Date: 4/3/2024
#   Location: Town Hall Seattle
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Hippie Sabotage (https://visitseattle.org/events/hippie-sabotage/):
#   Date: 4/3/2024
#   Location: Showbox SoDo
#   Type: Music
#   Region: Pioneer Square
#
# Details for Manual Cinema (https://visitseattle.org/events/manual-cinema/):
#   Date: 4/3/2024
#   Location: The Moore Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for Matt Maltese (https://visitseattle.org/events/matt-maltese/):
#   Date: 4/3/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for Aan (https://visitseattle.org/events/aan/):
#   Date: 4/4/2024
#   Location: Sunset Tavern
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Luis Miguel (https://visitseattle.org/events/luis-miguel/):
#   Date: 4/4/2024
#   Location: Climate Pledge Arena
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Taylor Raven and Duke Kim in Recital (https://visitseattle.org/events/taylor-raven-and-duke-kim-in-recital/):
#   Date: 4/4/2024
#   Location: Opera Center
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Arizona Zervas (https://visitseattle.org/events/arizona-zervas/):
#   Date: 4/5/2024
#   Location: Nectar Lounge
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Fatoumata Diawara (https://visitseattle.org/events/fatoumata-diawara/):
#   Date: 4/5/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for GARZA of Thievery Corporation (https://visitseattle.org/events/garza-of-thievery-corporation/):
#   Date: 4/5/2024
#   Location: Nectar Lounge
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Jo Koy (https://visitseattle.org/events/jo-koy/):
#   Date: 4/5/2024
#   Location: Climate Pledge Arena
#   Type: Theatre
#   Region: Queen Anne / Seattle Center
#
# Details for R.A.P. Ferreira (https://visitseattle.org/events/r-a-p-ferreira/):
#   Date: 4/5/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for The Veronicas (https://visitseattle.org/events/the-veronicas/):
#   Date: 4/5/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Weep Wave (https://visitseattle.org/events/weep-wave/):
#   Date: 4/5/2024
#   Location: Sunset Tavern
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for XAVI (https://visitseattle.org/events/xavi/):
#   Date: 4/5/2024
#   Location: Showbox SoDo
#   Type: Music
#   Region: Pioneer Square
#
# Details for Copland Appalachian Spring (https://visitseattle.org/events/copland-appalachian-spring/):
#   Date: 4/4/2024 through 4/6/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Asher Roth (https://visitseattle.org/events/asher-roth/):
#   Date: 4/6/2024
#   Location: Nectar Lounge
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Peekaboo (https://visitseattle.org/events/peekaboo/):
#   Date: 4/6/2024
#   Location: Showbox SoDo
#   Type: Music
#   Region: Pioneer Square
#
# Details for Red Bull Lords of Floor (https://visitseattle.org/events/red-bull-lords-of-floor/):
#   Date: 4/6/2024
#   Location: WaMu Theater
#   Type: Dance
#   Region: Pioneer Square
#
# Details for Seattle Sounders FC vs. CF Montreal (https://visitseattle.org/events/seattle-sounders-fc-vs-cf-montreal/):
#   Date: 4/6/2024
#   Location: Lumen Field
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Sultan and Shepard (https://visitseattle.org/events/sultan-and-shepard/):
#   Date: 4/6/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for The Nook: Rainbow Rhapsody (https://visitseattle.org/events/the-nook-rainbow-rhapsody/):
#   Date: 4/6/2024
#   Location: The Neptune Theatre
#   Type: Music
#   Region: University District
#
# Details for Tom Segura (https://visitseattle.org/events/tom-segura/):
#   Date: 4/6/2024
#   Location: Climate Pledge Arena
#   Type: Theatre
#   Region: Queen Anne / Seattle Center
#
# Details for Whose Live Anyway? (https://visitseattle.org/events/whose-live-anyway/):
#   Date: 4/6/2024
#   Location: The Moore Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for La Vaughn Belle: A History of Unruly Returns (https://visitseattle.org/events/la-vaughn-belle-a-history-of-unruly-returns/):
#   Date: Now through 4/7/2024
#   Location: National Nordic Museum
#   Type: Museums
#   Region: Fremont / Ballard
#
# Details for Beetlejuice (https://visitseattle.org/events/beetlejuice/):
#   Date: 4/2/2024 through 4/7/2024
#   Location: The Paramount Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for 31 Nights (https://visitseattle.org/events/31-nights/):
#   Date: 4/7/2024
#   Location: High Dive
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Mom Jeans (https://visitseattle.org/events/mom-jeans/):
#   Date: 4/7/2024
#   Location: Showbox SoDo
#   Type: Music
#   Region: Pioneer Square
#
# Details for Re + Re-TROS North America Tour (https://visitseattle.org/events/re-re-tros-north-america-tour/):
#   Date: 4/7/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for Varietopia (https://visitseattle.org/events/varietopia/):
#   Date: 4/7/2024 through 4/8/2024
#   Location: The Neptune Theatre
#   Type: Theatre
#   Region: University District
#
# Details for American Broke (https://visitseattle.org/events/american-broke/):
#   Date: 4/9/2024
#   Location: Sunset Tavern
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Seattle Kraken vs. Arizona Coyotes (https://visitseattle.org/events/seattle-kraken-vs-arizona-coyotes/):
#   Date: 4/9/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Stephanie Anne Johnson (https://visitseattle.org/events/stephanie-anne-johnson/):
#   Date: 4/9/2024 through 4/10/2024
#   Location: Dimitriou's Jazz Alley
#   Type: Music
#   Region: Downtown
#
# Details for Alice Phoebe Lou (https://visitseattle.org/events/alice-phoebe-lou/):
#   Date: 4/10/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for All of Our Cornbread (https://visitseattle.org/events/all-of-our-cornbread/):
#   Date: 4/10/2024
#   Location: Sunset Tavern
#   Type: Music
#   Region: Fremont / Ballard
#
# Details for Hot Rod (https://visitseattle.org/events/hot-rod/):
#   Date: 4/10/2024
#   Location: Sea Monster Lounge
#   Type: Music
#   Region: Wallingford / Greenlake
#
# Details for Hurricane Dreamz (https://visitseattle.org/events/hurricane-dreamz/):
#   Date: 4/10/2024
#   Location: Sea Monster Lounge
#   Type: Music
#   Region: Wallingford / Greenlake
#
# Details for Kronos Quartet (https://visitseattle.org/events/kronos-quartet/):
#   Date: 4/11/2024
#   Location: The Moore Theatre
#   Type: Music
#   Region: Downtown
#
# Details for Rising Star Project: Something’s Afoot (https://visitseattle.org/events/rising-star-project-somethings-afoot/):
#   Date: 4/11/2024
#   Location: The 5th Avenue Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for Seattle Kraken vs. San Jose Sharks (https://visitseattle.org/events/seattle-kraken-vs-san-jose-sharks/):
#   Date: 4/11/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Felipe Esparza (https://visitseattle.org/events/felipe-esparza/):
#   Date: 4/12/2024
#   Location: The Neptune Theatre
#   Type: Theatre
#   Region: University District
#
# Details for Set It Off (https://visitseattle.org/events/set-it-off/):
#   Date: 4/12/2024
#   Location: The Showbox
#   Type: Music
#   Region: Downtown
#
# Details for The Percussion: Sounds from Home (https://visitseattle.org/events/the-percussion-sounds-from-home/):
#   Date: 4/12/2024 through 4/13/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Afrobeats to the World (https://visitseattle.org/events/afrobeats-to-the-world/):
#   Date: 4/13/2024
#   Location: The Crocodile
#   Type: Music
#   Region: Downtown
#
# Details for Sasha Colby: Stripped Tour (https://visitseattle.org/events/sasha-colby-stripped-tour/):
#   Date: 4/13/2024
#   Location: The Neptune Theatre
#   Type: Theatre
#   Region: University District
#
# Details for Squirt (https://visitseattle.org/events/squirt/):
#   Date: 4/13/2024
#   Location: Slim's Last Chance
#   Type: Music
#   Region: South Seattle
#
# Details for Tina Fey and Amy Poehler: Restless Leg Tour (https://visitseattle.org/events/tina-fey-and-amy-poehler-restless-leg-tour/):
#   Date: 4/13/2024
#   Location: WaMu Theater
#   Type: Theatre
#   Region: Pioneer Square
#
# Details for Honoring 50 Years of Papunya Tula Painting (https://visitseattle.org/events/honoring-50-years-of-papunya-tula-painting/):
#   Date: Now through 4/14/2024
#   Location: Seattle Art Museum
#   Type: Museums
#   Region: Downtown
#
# Details for The Moors (https://visitseattle.org/events/the-moors/):
#   Date: 3/22/2024 through 4/14/2024
#   Location: Seattle Public Theater
#   Type: Theatre
#   Region: Wallingford / Greenlake
#
# Details for Jose Feliciano (https://visitseattle.org/events/jose-feliciano/):
#   Date: 4/11/2024 through 4/14/2024
#   Location: Dimitriou's Jazz Alley
#   Type: Music
#   Region: Downtown
#
# Details for Mahler Symphony No. 3 (https://visitseattle.org/events/mahler-symphony-no-3/):
#   Date: 4/11/2024 through 4/14/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Festal: Seattle Cherry Blossom & Japanese Cultural Festival (https://visitseattle.org/events/festal-seattle-cherry-blossom-japanese-cultural-festival/):
#   Date: 4/12/2024 through 4/14/2024
#   Location: Seattle Center
#   Type: Festivals & Special Events
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Mariners vs. Chicago Cubs (https://visitseattle.org/events/seattle-mariners-vs-chicago-cubs/):
#   Date: 4/12/2024 through 4/14/2024
#   Location: T-Mobile Park
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Best of the Northwest Spring Show (https://visitseattle.org/events/best-of-the-northwest-spring-show/):
#   Date: 4/13/2024 through 4/14/2024
#   Location: Magnuson Park
#   Type: Festivals & Special Events
#   Region: University District
#
# Details for Neil deGrasse Tyson (https://visitseattle.org/events/neil-degrasse-tyson/):
#   Date: 4/15/2024 through 4/16/2024
#   Location: The Paramount Theatre
#   Type: Readings & Lectures
#   Region: Downtown
#
# Details for Seattle Mariners vs. Cincinnati Reds (https://visitseattle.org/events/seattle-mariners-vs-cincinnati-reds/):
#   Date: 4/15/2024 through 4/17/2024
#   Location: T-Mobile Park
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Matthew Whitaker Quintet (https://visitseattle.org/events/matthew-whitaker-quintet/):
#   Date: 4/16/2024 through 4/17/2024
#   Location: Dimitriou's Jazz Alley
#   Type: Music
#   Region: Downtown
#
# Details for An Evening with Jinjoo Cho (https://visitseattle.org/events/an-evening-with-jinjoo-cho/):
#   Date: 4/19/2024
#   Location: 415 Westlake
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Hasan Minhaj (https://visitseattle.org/events/hasan-minhaj/):
#   Date: 4/19/2024
#   Location: The Paramount Theatre
#   Type: Theatre
#   Region: Downtown
#
# ...
#   Date: 5/9/2024 through 5/19/2024
#   Location: Seattle, WA
#   Type: Festivals & Special Events
#   Region: Downtown
#
# Details for U District Street Fair (https://visitseattle.org/events/u-district-street-fair/):
#   Date: 5/18/2024 through 5/19/2024
#   Location: Seattle, WA
#   Type: Festivals & Special Events
#   Region: Downtown
#
# Details for Madness (https://visitseattle.org/events/madness/):
#   Date: 5/22/2024
#   Location: WaMu Theater
#   Type: Music
#   Region: Pioneer Square
#
# Details for Seattle Storm vs. Indiana Fever (https://visitseattle.org/events/seattle-storm-vs-indiana-fever/):
#   Date: 5/22/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for The Barber of Seville (https://visitseattle.org/events/the-barber-of-seville/):
#   Date: 5/4/2024 through 5/24/2024
#   Location: Marion Oliver McCaw Hall
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Storm vs. Washington Mystics (https://visitseattle.org/events/seattle-storm-vs-washington-mystics/):
#   Date: 5/25/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for 53rd Annual Northwest Folklife Festival (https://visitseattle.org/events/53rd-annual-northwest-folklife-festival/):
#   Date: 5/24/2024 through 5/27/2024
#   Location: Seattle Center
#   Type: Festivals & Special Events
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Sounders FC vs. Real Salt Lake (https://visitseattle.org/events/seattle-sounders-fc-vs-real-salt-lake/):
#   Date: 5/29/2024
#   Location: Lumen Field
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Seattle Mariners vs. Houston Astros (https://visitseattle.org/events/seattle-mariners-vs-houston-astros/):
#   Date: 5/27/2024 through 5/30/2024
#   Location: T-Mobile Park
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Caifanes and Cafe Tacvba (https://visitseattle.org/events/caifanes-and-cafe-tacvba/):
#   Date: 5/30/2024
#   Location: WaMu Theater
#   Type: Music
#   Region: Pioneer Square
#
# Details for Unriveled (https://visitseattle.org/events/unriveled/):
#   Date: 5/10/2024 through 6/2/2024
#   Location: Seattle Public Theater
#   Type: Theatre
#   Region: Wallingford / Greenlake
#
# Details for Seattle Mariners vs. Los Angeles Angels (https://visitseattle.org/events/seattle-mariners-vs-los-angeles-angels/):
#   Date: 5/30/2024 through 6/2/2024
#   Location: T-Mobile Park
#   Type: Sports
#   Region: Pioneer Square
#
# Details for HONK! Fest West (https://visitseattle.org/events/honk-fest-west/):
#   Date: 5/31/2024 through 6/2/2024
#   Location: Seattle, WA
#   Type: Festivals & Special Events
#   Region: Downtown
#
# Details for Festal: Pagdiriwang Philippine Festival (https://visitseattle.org/events/festal-pagdiriwang-philippine-festival/):
#   Date: 6/1/2024 through 6/2/2024
#   Location: Seattle Center
#   Type: Festivals & Special Events
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Storm vs. Phoenix Mercury (https://visitseattle.org/events/seattle-storm-vs-phoenix-mercury/):
#   Date: 6/4/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Festal: Indigenous People Festival (https://visitseattle.org/events/festal-indigenous-people-festival/):
#   Date: 6/8/2024
#   Location: Seattle Center
#   Type: Festivals & Special Events
#   Region: Queen Anne / Seattle Center
#
# Details for George Balenchine’s Coppelia (https://visitseattle.org/events/george-balenchines-coppelia/):
#   Date: 5/31/2024 through 6/9/2024
#   Location: Marion Oliver McCaw Hall
#   Type: Dance
#   Region: Queen Anne / Seattle Center
#
# Details for Jan Lisiecki Plays Prokofiev (https://visitseattle.org/events/jan-lisiecki-plays-prokofiev/):
#   Date: 6/6/2024 through 6/9/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Seattle Storm vs. Los Angeles Sparks (https://visitseattle.org/events/seattle-storm-vs-los-angeles-sparks/):
#   Date: 6/11/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Mariners vs. Chicago White Sox (https://visitseattle.org/events/seattle-mariners-vs-chicago-white-sox/):
#   Date: 6/10/2024 through 6/12/2024
#   Location: T-Mobile Park
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Third Eye Blind (https://visitseattle.org/events/third-eye-blind/):
#   Date: 6/13/2024
#   Location: WaMu Theater
#   Type: Music
#   Region: Pioneer Square
#
# Details for Beethoven Symphony No. 5 (https://visitseattle.org/events/beethoven-symphony-no-5/):
#   Date: 6/13/2024 through 6/15/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Elizabeth Malaska: All Be Your Mirror (https://visitseattle.org/events/elizabeth-malaska-all-be-your-mirror/):
#   Date: Now through 6/16/2024
#   Location: Seattle Art Museum
#   Type: Museums
#   Region: Downtown
#
# Details for Seattle Mariners vs. Texas Rangers (https://visitseattle.org/events/seattle-mariners-vs-texas-rangers/):
#   Date: 6/14/2024 through 6/16/2024
#   Location: T-Mobile Park
#   Type: Sports
#   Region: Pioneer Square
#
# Details for ZooTunes: Mother Mother/Cavetown (https://visitseattle.org/events/zootunes-mother-mother-cavetown/):
#   Date: 6/16/2024
#   Location: Woodland Park Zoo
#   Type: Music
#   Region: Wallingford / Greenlake
#
# Details for ZooTunes: Car Seat Headrest (https://visitseattle.org/events/zootunes-car-seat-headrest/):
#   Date: 6/20/2024
#   Location: Woodland Park Zoo
#   Type: Music
#   Region: Wallingford / Greenlake
#
# Details for Joshua Bell Plays Elements Concerto (https://visitseattle.org/events/joshua-bell-plays-elements-concerto/):
#   Date: 6/20/2024 through 6/22/2024
#   Location: Benaroya Hall
#   Type: Music
#   Region: Downtown
#
# Details for Festal: Seattle Iranian Festival (https://visitseattle.org/events/festal-seattle-iranian-festival/):
#   Date: 6/22/2024
#   Location: Seattle Center
#   Type: Festivals & Special Events
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Sounders FC vs. Minnesota United FC (https://visitseattle.org/events/seattle-sounders-fc-vs-minnesota-united-fc/):
#   Date: 6/22/2024
#   Location: Lumen Field
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Together Again, Again! (https://visitseattle.org/events/together-again-again/):
#   Date: 5/31/2024 through 6/23/2024
#   Location: Seattle Rep
#   Type: Theatre
#   Region: Queen Anne / Seattle Center
#
# Details for 2024 KPMG Women’s PGA Championship (https://visitseattle.org/events/2024-kpmg-womens-pga-championship/):
#   Date: 6/20/2024 through 6/23/2024
#   Location: Sahalee Country Club
#   Type: Sports
#   Region: Bellevue / Eastside
#
# Details for Fremont Fair (https://visitseattle.org/events/fremont-fair/):
#   Date: 6/22/2024 through 6/23/2024
#   Location: Fremont Fair
#   Type: Festivals & Special Events
#   Region: Fremont/ Ballard
#
# Details for Lip Sync for Our Rights (https://visitseattle.org/events/lip-sync-for-our-rights/):
#   Date: 6/22/2024 through 6/23/2024
#   Location: Marion Oliver McCaw Hall
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Storm vs. Connecticut Sun (https://visitseattle.org/events/seattle-storm-vs-connecticut-sun/):
#   Date: 6/23/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Storm vs. Indiana Fever (https://visitseattle.org/events/seattle-storm-vs-indiana-fever-2/):
#   Date: 6/27/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Company (https://visitseattle.org/events/company/):
#   Date: 6/23/2024 through 6/28/2024
#   Location: The Paramount Theatre
#   Type: Music
#   Region: Downtown
#
# Details for Seattle Storm vs. Dallas Wings (https://visitseattle.org/events/seattle-storm-vs-dallas-wings/):
#   Date: 6/29/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Sounders FC vs. Chicago Fire FC (https://visitseattle.org/events/sounders-fc-vs-chicago-fire-fc/):
#   Date: 6/29/2024
#   Location: Lumen Field
#   Type: Sports
#   Region: Pioneer Square
#
# Details for 2024 University of Washington MFA + MDes Thesis Exhibition (https://visitseattle.org/events/2024-university-of-washington-mfa-mdes-thesis-exhibition/):
#   Date: 5/24/2024 through 6/30/2024
#   Location: Henry Art Gallery
#   Type: Museums
#   Region: University District
#
# Details for Spring Awakening (https://visitseattle.org/events/spring-awakening/):
#   Date: 6/7/2024 through 6/30/2024
#   Location: The 5th Avenue Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for Girl From The North Country (https://visitseattle.org/events/girl-from-the-north-country/):
#   Date: 6/25/2024 through 6/30/2024
#   Location: The Paramount Theatre
#   Type: Music
#   Region: Downtown
#
# Details for Seattle Mariners vs. Minnesota Twins (https://visitseattle.org/events/seattle-mariners-vs-minnesota-twins/):
#   Date: 6/28/2024 through 6/30/2024
#   Location: T-Mobile Park
#   Type: Sports
#   Region: Pioneer Square
#
# Details for 50th Annual Seattle Pride Parade 2024 (https://visitseattle.org/events/50th-annual-seattle-pride-parade-2024/):
#   Date: 6/30/2024
#   Location: Seattle, WA
#   Type: Festivals & Special Events
#   Region: Downtown
#
# Details for Seattle Storm vs Dallas Wings (https://visitseattle.org/events/seattle-storm-vs-dallas-wings-2/):
#   Date: 7/1/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Mariners vs. Baltimore Orioles (https://visitseattle.org/events/seattle-mariners-vs-baltimore-orioles/):
#   Date: 7/2/2024 through 7/4/2024
#   Location: T-Mobile Park
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Amazon Seafair Summer Fourth (https://visitseattle.org/events/amazon-seafair-summer-fourth/):
#   Date: 7/4/2024
#   Location: Gas Works Park
#   Type: Festivals & Special Events
#   Region: Wallingford / Greenlake
#
# Details for Seattle Storm vs. Chicago Sky (https://visitseattle.org/events/seattle-storm-vs-chicago-sky/):
#   Date: 7/5/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Sounders FC vs. New England Revolution (https://visitseattle.org/events/seattle-sounders-fc-vs-new-england-revolution/):
#   Date: 7/6/2024
#   Location: Lumen Field
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Anida Yoeu Ali: Hybrid Skin, Mythical Presence (https://visitseattle.org/events/anida-yoeu-ali-hybrid-skin-mythical-presence/):
#   Date: Now through 7/7/2024
#   Location: Seattle Asian Art Museum
#   Type: Museums
#   Region: Capitol Hill / Central District
#
# Details for Seattle Mariners vs. Toronto Blue Jays (https://visitseattle.org/events/seattle-mariners-vs-toronto-blue-jays/):
#   Date: 7/5/2024 through 7/7/2024
#   Location: T-Mobile Park
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Seattle Storm vs.Chicago Sky (https://visitseattle.org/events/seattle-storm-vs-chicago-sky-2/):
#   Date: 7/7/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Storm vs. Las Vegas Aces (https://visitseattle.org/events/seattle-storm-vs-las-vegas-aces/):
#   Date: 7/10/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Storm vs. Minnesota Lynx (https://visitseattle.org/events/seattle-storm-vs-minnesota-lynx-2/):
#   Date: 7/12/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Festal: Polish Festival Seattle (https://visitseattle.org/events/festal-polish-festival-seattle/):
#   Date: 7/13/2024
#   Location: Seattle Center
#   Type: Festivals & Special Events
#   Region: Queen Anne / Seattle Center
#
# Details for Kenny Chesney with Zac Brown Band (https://visitseattle.org/events/kenny-chesney-with-zac-brown-band/):
#   Date: 7/13/2024
#   Location: Lumen Field
#   Type: Music
#   Region: Pioneer Square
#
# Details for Ballard SeafoodFest (https://visitseattle.org/events/ballard-seafoodfest/):
#   Date: 7/12/2024 through 7/14/2024
#   Location: Ballard Neighborhood
#   Type: Festivals & Special Events
#   Region: Fremont / Ballard
#
# Details for Day In Day Out Festival (https://visitseattle.org/events/day-in-day-out-festival/):
#   Date: 7/12/2024 through 7/14/2024
#   Location: Fisher Pavilion
#   Type: Music
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Storm vs. Atlanta Dream (https://visitseattle.org/events/seattle-storm-vs-atlanta-dream/):
#   Date: 7/14/2024
#   Location: Climate Pledge Arena
#   Type: Sports
#   Region: Queen Anne / Seattle Center
#
# Details for Seattle Sounders FC vs. St. Louis SC (https://visitseattle.org/events/seattle-sounders-fc-vs-st-louis-sc/):
#   Date: 7/17/2024
#   Location: Lumen Field
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Seattle Sounders FC vs. Los Angeles FC (https://visitseattle.org/events/seattle-sounders-fc-vs-los-angeles-fc/):
#   Date: 7/20/2024
#   Location: Lumen Field
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Nordic Utopia: African Americans in the 20th Century (https://visitseattle.org/events/nordic-utopia-african-americans-in-the-20th-century/):
#   Date: 3/22/2024 through 7/21/2024
#   Location: National Nordic Museum
#   Type: Museums
#   Region: Fremont / Ballard
#
# Details for Clue (https://visitseattle.org/events/clue/):
#   Date: 7/9/2024 through 7/21/2024
#   Location: The 5th Avenue Theatre
#   Type: Theatre
#   Region: Downtown
#
# Details for 35th Annual Seafair Indian Days Powwow (https://visitseattle.org/events/35th-annual-seafair-indian-days-powwow/):
#   Date: 7/19/2024 through 7/21/2024
#   Location: Daybreak Star Indian Cultural Center
#   Type: Festivals & Special Events
#   Region: Queen Anne / Seattle Center
#
# Details for Capitol Hill Block Party (https://visitseattle.org/events/capitol-hill-block-party/):
#   Date: 7/19/2024 through 7/21/2024
#   Location: Capitol Hill Block Party
#   Type: Festivals & Special Events
#   Region: Capitol Hill / Central District
#
# Details for Seattle Mariners vs. Houston Astros (https://visitseattle.org/events/seattle-mariners-vs-houston-astros-2/):
#   Date: 7/19/2024 through 7/21/2024
#   Location: T-Mobile Park
#   Type: Sports
#   Region: Pioneer Square
#
# Details for Seafair Triathlon (https://visitseattle.org/events/seafair-triathlon/):
#   Date: 7/21/2024
#   Location: Seward Park
#   Type: Festivals & Special Events
#   Region: South Seattle
#
# Details for ZooTunes: The Roots (https://visitseattle.org/events/zootunes-the-roots/):
#   Date: 7/21/2024
#   Location: Woodland Park Zoo
#   Type: Music
#   Region: Wallingford / Greenlake
#
# Details for Seattle Mariners vs. Los Angeles Angels (https://visitseattle.org/events/seattle-mariners-vs-los-angeles-angels-2/):
#   Date: 7/22/2024 through 7/24/2024
#   Location: T-Mobile Park
#   Type: Sports
#   Region: Pioneer Square
#
# Details for ZooTunes: Violent Femmes (https://visitseattle.org/events/zootunes-violent-femmes/):
#   Date: 7/25/2024
#   Location: Woodland Park Zoo
#   Type: Music
#   Region: Wallingford / Greenlake
#
# Details for Alaska Airlines Torchlight Parade (https://visitseattle.org/events/alaska-airlines-torchlight-parade/):
#   Date: 7/27/2024
#   Location: Westlake Park
#   Type: Festivals & Special Events
#   Region: Downtown
#
# Details for Be Water, My Friend: The Teachings Of Bruce Lee (https://visitseattle.org/events/be-water-my-friend-the-teachings-of-bruce-lee/):
#   Date: Now through 7/28/2024
#   Location: Wing Luke Museum
#   Type: Museums
#   Region: International District
#
# Details for Seattle Art Fair (https://visitseattle.org/events/seattle-art-fair/):
#   Date: 7/25/2024 through 7/28/2024
#   Location: Lumen Field
#   Type: Festivals & Special Events
#   Region: Pioneer Square
#
# Details for Festal: Seattle Arab Festival (https://visitseattle.org/events/festal-seattle-arab-festival/):
#   Date: 7/27/2024 through 7/28/2024
#   Location: Seattle Center
#   Type: Festivals & Special Events
#   Region: Queen Anne / Seattle Center
#
# Details for ZooTunes: Norah Jones (https://visitseattle.org/events/zootunes-norah-jones/):
#   Date: 7/29/2024
#   Location: Woodland Park Zoo
#   Type: Music
#   Region: Wallingford / Greenlake
#
# Event details stored in events.csv

# %% [markdown]
# # Weather API

# %%
import requests

# %%
url = "https://api.weather.gov/points/39.7456,-97.0892"
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '{\n    "@context": [\n        "https://geojson.org/geojson-ld/geojson-context.jsonld",\n        {\n            "@version": "1.1",\n            "wx": "https://api.weather.gov/ontology#",\n            "s": "https://schema.org/",\n            "geo": "http://www.opengis.net/ont/geosparql#",\n            "unit": "http://codes.wmo.int/common/unit/",\n            "@vocab": "https://api.weather.gov/ontology#",\n            "geometry": {\n                "@id": "s:GeoCoordinates",\n                "@type": "geo:wktLiteral"\n            },\n            "city": "s:addressLocality",\n            "state": "s:addressRegion",\n            "distance": {\n                "@id": "s:Distance",\n                "@type": "s:QuantitativeValue"\n            },\n            "bearing": {\n                "@type": "s:QuantitativeValue"\n            },\n            "value": {\n                "@id": "s:value"\n            },\n            "unitCode": {\n                "@id": "s:unitCode",\n                "@type": "@id"\n            },\n            "forecastOffice": {\n                "@type": "@id"\n            },\n            "forecastGridData": {\n                "@type": "@id"\n            },\n            "publicZone": {\n                "@type": "@id"\n            },\n            "county": {\n                "@type": "@id"\n            }\n        }\n    ],\n    "id": "https://api.weather.gov/points/39.7456,-97.0892",\n    "type": "Feature",\n    "geometry": {\n        "type": "Point",\n        "coordinates": [\n            -97.089200000000005,\n            39.745600000000003\n        ]\n    },\n    "properties": {\n        "@id": "https://api.weather.gov/points/39.7456,-97.0892",\n        "@type": "wx:Point",\n        "cwa": "TOP",\n        "forecastOffice": "https://api.weather.gov/offices/TOP",\n        "gridId": "TOP",\n        "gridX": 32,\n        "gridY": 81,\n        "forecast": "https://api.weather.gov/gridpoints/TOP/32,81/forecast",\n        "forecastHourly": "https://api.weather.gov/gridpoints/TOP/32,81/forecast/hourly",\n        "forecastGridData": "https://api.weather.gov/gridpoints/TOP/32,81",\n        "observationStations": "https://api.weather.gov/gridpoints/TOP/32,81/stations",\n        "relativeLocation": {\n            "type": "Feature",\n            "geometry": {\n                "type": "Point",\n                "coordinates": [\n                    -97.086661000000007,\n                    39.679375999999998\n                ]\n            },\n            "properties": {\n                "city": "Linn",\n                "state": "KS",\n                "distance": {\n                    "unitCode": "wmoUnit:m",\n                    "value": 7366.9851976443997\n                },\n                "bearing": {\n                    "unitCode": "wmoUnit:degree_(angle)",\n                    "value": 358\n                }\n            }\n        },\n        "forecastZone": "https://api.weather.gov/zones/forecast/KSZ009",\n        "county": "https://api.weather.gov/zones/county/KSC201",\n        "fireWeatherZone": "https://api.weather.gov/zones/fire/KSZ009",\n        "timeZone": "America/Chicago",\n        "radarStation": "KTWX"\n    }\n}'

# %%
point_dict = res.json()
point_dict
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#   {'@version': '1.1',
#    'wx': 'https://api.weather.gov/ontology#',
#    's': 'https://schema.org/',
#    'geo': 'http://www.opengis.net/ont/geosparql#',
#    'unit': 'http://codes.wmo.int/common/unit/',
#    '@vocab': 'https://api.weather.gov/ontology#',
#    'geometry': {'@id': 's:GeoCoordinates', '@type': 'geo:wktLiteral'},
#    'city': 's:addressLocality',
#    'state': 's:addressRegion',
#    'distance': {'@id': 's:Distance', '@type': 's:QuantitativeValue'},
#    'bearing': {'@type': 's:QuantitativeValue'},
#    'value': {'@id': 's:value'},
#    'unitCode': {'@id': 's:unitCode', '@type': '@id'},
#    'forecastOffice': {'@type': '@id'},
#    'forecastGridData': {'@type': '@id'},
#    'publicZone': {'@type': '@id'},
#    'county': {'@type': '@id'}}],
#  'id': 'https://api.weather.gov/points/39.7456,-97.0892',
#  'type': 'Feature',
#  'geometry': {'type': 'Point', 'coordinates': [-97.0892, 39.7456]},
#  'properties': {'@id': 'https://api.weather.gov/points/39.7456,-97.0892',
#   '@type': 'wx:Point',
#   'cwa': 'TOP',
#   'forecastOffice': 'https://api.weather.gov/offices/TOP',
#   'gridId': 'TOP',
#   'gridX': 32,
#   'gridY': 81,
#   'forecast': 'https://api.weather.gov/gridpoints/TOP/32,81/forecast',
#   'forecastHourly': 'https://api.weather.gov/gridpoints/TOP/32,81/forecast/hourly',
#   'forecastGridData': 'https://api.weather.gov/gridpoints/TOP/32,81',
#   'observationStations': 'https://api.weather.gov/gridpoints/TOP/32,81/stations',
#   'relativeLocation': {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-97.086661, 39.679376]},
#    'properties': {'city': 'Linn',
#     'state': 'KS',
#     'distance': {'unitCode': 'wmoUnit:m', 'value': 7366.9851976444},
#     'bearing': {'unitCode': 'wmoUnit:degree_(angle)', 'value': 358}}},
#   'forecastZone': 'https://api.weather.gov/zones/forecast/KSZ009',
#   'county': 'https://api.weather.gov/zones/county/KSC201',
#   'fireWeatherZone': 'https://api.weather.gov/zones/fire/KSZ009',
#   'timeZone': 'America/Chicago',
#   'radarStation': 'KTWX'}}

# %%
point_dict.keys()
# Out:
# dict_keys(['@context', 'id', 'type', 'geometry', 'properties'])

# %%
forcast_url = point_dict['properties']['forecast']
forcast_url
# Out:
# 'https://api.weather.gov/gridpoints/TOP/32,81/forecast'

# %%
res = requests.get(forcast_url)
res.json()
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#   {'@version': '1.1',
#    'wx': 'https://api.weather.gov/ontology#',
#    'geo': 'http://www.opengis.net/ont/geosparql#',
#    'unit': 'http://codes.wmo.int/common/unit/',
#    '@vocab': 'https://api.weather.gov/ontology#'}],
#  'type': 'Feature',
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-97.1089731, 39.7668263],
#     [-97.1085269, 39.7447788],
#     [-97.0798467, 39.7451195],
#     [-97.08028680000001, 39.767167],
#     [-97.1089731, 39.7668263]]]},
#  'properties': {'updated': '2024-03-08T19:41:18+00:00',
#   'units': 'us',
#   'forecastGenerator': 'BaselineForecastGenerator',
#   'generatedAt': '2024-03-08T20:10:59+00:00',
#   'updateTime': '2024-03-08T19:41:18+00:00',
#   'validTimes': '2024-03-08T13:00:00+00:00/P7DT12H',
#   'elevation': {'unitCode': 'wmoUnit:m', 'value': 441.96},
#   'periods': [{'number': 1,
#     'name': 'This Afternoon',
#     'startTime': '2024-03-08T14:00:00-06:00',
#     'endTime': '2024-03-08T18:00:00-06:00',
#     'isDaytime': True,
#     'temperature': 38,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 20},
#     'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.3333333333333335},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 75},
#     'windSpeed': '15 to 20 mph',
#     'windDirection': 'N',
#     'icon': 'https://api.weather.gov/icons/land/day/snow,20?size=medium',
#     'shortForecast': 'Slight Chance Light Snow',
#     'detailedForecast': 'A slight chance of snow before 4pm. Cloudy, with a high near 38. North wind 15 to 20 mph, with gusts as high as 30 mph. Chance of precipitation is 20%.'},
#    {'number': 2,
#     'name': 'Tonight',
#     'startTime': '2024-03-08T18:00:00-06:00',
#     'endTime': '2024-03-09T06:00:00-06:00',
#     'isDaytime': False,
#     'temperature': 23,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#      'value': None},
#     'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -3.3333333333333335},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 84},
#     'windSpeed': '10 to 15 mph',
#     'windDirection': 'N',
#     'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#     'shortForecast': 'Partly Cloudy',
#     'detailedForecast': 'Partly cloudy, with a low around 23. North wind 10 to 15 mph, with gusts as high as 25 mph.'},
#    {'number': 3,
#     'name': 'Saturday',
#     'startTime': '2024-03-09T06:00:00-06:00',
#     'endTime': '2024-03-09T18:00:00-06:00',
#     'isDaytime': True,
#     'temperature': 52,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#      'value': None},
#     'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -4.444444444444445},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 84},
#     'windSpeed': '10 to 15 mph',
#     'windDirection': 'NW',
#     'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#     'shortForecast': 'Sunny',
#     'detailedForecast': 'Sunny, with a high near 52. Northwest wind 10 to 15 mph, with gusts as high as 20 mph.'},
#    {'number': 4,
#     'name': 'Saturday Night',
#     'startTime': '2024-03-09T18:00:00-06:00',
#     'endTime': '2024-03-10T06:00:00-05:00',
#     'isDaytime': False,
#     'temperature': 26,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#      'value': None},
#     'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': -5},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 78},
#     'windSpeed': '5 to 10 mph',
#     'windDirection': 'W',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'shortForecast': 'Clear',
#     'detailedForecast': 'Clear, with a low around 26. West wind 5 to 10 mph.'},
#    {'number': 5,
#     'name': 'Sunday',
#     'startTime': '2024-03-10T06:00:00-05:00',
#     'endTime': '2024-03-10T18:00:00-05:00',
#     'isDaytime': True,
#     'temperature': 64,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#      'value': None},
#     'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 0.5555555555555556},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 81},
#     'windSpeed': '5 to 15 mph',
#     'windDirection': 'SW',
#     'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#     'shortForecast': 'Sunny',
#     'detailedForecast': 'Sunny, with a high near 64. Southwest wind 5 to 15 mph, with gusts as high as 25 mph.'},
#    {'number': 6,
#     'name': 'Sunday Night',
#     'startTime': '2024-03-10T18:00:00-05:00',
#     'endTime': '2024-03-11T06:00:00-05:00',
#     'isDaytime': False,
#     'temperature': 38,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#      'value': None},
#     'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 1.1111111111111112},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 75},
#     'windSpeed': '10 to 15 mph',
#     'windDirection': 'S',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'shortForecast': 'Clear',
#     'detailedForecast': 'Clear, with a low around 38. South wind 10 to 15 mph, with gusts as high as 25 mph.'},
#    {'number': 7,
#     'name': 'Monday',
#     'startTime': '2024-03-11T06:00:00-05:00',
#     'endTime': '2024-03-11T18:00:00-05:00',
#     'isDaytime': True,
#     'temperature': 69,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#      'value': None},
#     'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 2.7777777777777777},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 76},
#     'windSpeed': '15 to 20 mph',
#     'windDirection': 'S',
#     'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#     'shortForecast': 'Sunny',
#     'detailedForecast': 'Sunny, with a high near 69. South wind 15 to 20 mph, with gusts as high as 35 mph.'},
#    {'number': 8,
#     'name': 'Monday Night',
#     'startTime': '2024-03-11T18:00:00-05:00',
#     'endTime': '2024-03-12T06:00:00-05:00',
#     'isDaytime': False,
#     'temperature': 47,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#      'value': None},
#     'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.3333333333333335},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 67},
#     'windSpeed': '20 mph',
#     'windDirection': 'S',
#     'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#     'shortForecast': 'Partly Cloudy',
#     'detailedForecast': 'Partly cloudy, with a low around 47. South wind around 20 mph, with gusts as high as 35 mph.'},
#    {'number': 9,
#     'name': 'Tuesday',
#     'startTime': '2024-03-12T06:00:00-05:00',
#     'endTime': '2024-03-12T18:00:00-05:00',
#     'isDaytime': True,
#     'temperature': 70,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#      'value': None},
#     'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 5},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 74},
#     'windSpeed': '15 to 20 mph',
#     'windDirection': 'W',
#     'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#     'shortForecast': 'Mostly Sunny',
#     'detailedForecast': 'Mostly sunny, with a high near 70. West wind 15 to 20 mph, with gusts as high as 30 mph.'},
#    {'number': 10,
#     'name': 'Tuesday Night',
#     'startTime': '2024-03-12T18:00:00-05:00',
#     'endTime': '2024-03-13T06:00:00-05:00',
#     'isDaytime': False,
#     'temperature': 41,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent',
#      'value': None},
#     'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 2.7777777777777777},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 76},
#     'windSpeed': '10 mph',
#     'windDirection': 'N',
#     'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#     'shortForecast': 'Partly Cloudy',
#     'detailedForecast': 'Partly cloudy, with a low around 41.'},
#    {'number': 11,
#     'name': 'Wednesday',
#     'startTime': '2024-03-13T06:00:00-05:00',
#     'endTime': '2024-03-13T18:00:00-05:00',
#     'isDaytime': True,
#     'temperature': 70,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 30},
#     'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 7.777777777777778},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 79},
#     'windSpeed': '10 to 15 mph',
#     'windDirection': 'SE',
#     'icon': 'https://api.weather.gov/icons/land/day/rain,20/rain,30?size=medium',
#     'shortForecast': 'Chance Light Rain',
#     'detailedForecast': 'A chance of rain after 7am. Partly sunny, with a high near 70. Chance of precipitation is 30%.'},
#    {'number': 12,
#     'name': 'Wednesday Night',
#     'startTime': '2024-03-13T18:00:00-05:00',
#     'endTime': '2024-03-14T06:00:00-05:00',
#     'isDaytime': False,
#     'temperature': 43,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 50},
#     'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 7.777777777777778},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 86},
#     'windSpeed': '15 mph',
#     'windDirection': 'NE',
#     'icon': 'https://api.weather.gov/icons/land/night/rain,50?size=medium',
#     'shortForecast': 'Chance Light Rain',
#     'detailedForecast': 'A chance of rain. Mostly cloudy, with a low around 43. Chance of precipitation is 50%.'},
#    {'number': 13,
#     'name': 'Thursday',
#     'startTime': '2024-03-14T06:00:00-05:00',
#     'endTime': '2024-03-14T18:00:00-05:00',
#     'isDaytime': True,
#     'temperature': 61,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 40},
#     'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 6.666666666666667},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 93},
#     'windSpeed': '15 to 20 mph',
#     'windDirection': 'N',
#     'icon': 'https://api.weather.gov/icons/land/day/rain,40?size=medium',
#     'shortForecast': 'Chance Light Rain',
#     'detailedForecast': 'A chance of rain. Partly sunny, with a high near 61. Chance of precipitation is 40%.'},
#    {'number': 14,
#     'name': 'Thursday Night',
#     'startTime': '2024-03-14T18:00:00-05:00',
#     'endTime': '2024-03-15T06:00:00-05:00',
#     'isDaytime': False,
#     'temperature': 35,
#     'temperatureUnit': 'F',
#     'temperatureTrend': None,
#     'probabilityOfPrecipitation': {'unitCode': 'wmoUnit:percent', 'value': 30},
#     'dewpoint': {'unitCode': 'wmoUnit:degC', 'value': 3.888888888888889},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent', 'value': 81},
#     'windSpeed': '15 to 20 mph',
#     'windDirection': 'N',
#     'icon': 'https://api.weather.gov/icons/land/night/rain,30/rain,20?size=medium',
#     'shortForecast': 'Chance Light Rain',
#     'detailedForecast': 'A chance of rain. Mostly cloudy, with a low around 35. Chance of precipitation is 30%.'}]}}

# %%
# def get_weather(lat, lon):
#     weather_url = f"https://api.weather.gov/points/{lat},{lon}"
#     weather_response = requests.get(weather_url)
#     weather_data = weather_response.json()
#     res = requests.get(weather_url)
#     point_dict = res.json()
#     forecast_url = point_dict['properties']['forecast']
#     res_forecast = requests.get(forecast_url)
#     weather_data = res_forecast.json()
#     point_dict= res_forecast.json()
#     forecast = weather_data['properties']['periods'][0]['detailedForecast']
#     return forecast

# %%
def get_weather(lat, lon):
    weather_url = f"https://api.weather.gov/points/{lat},{lon}"
    response = requests.get(weather_url)

    if response.status_code == 200:
        data = response.json()
        forecast_url = data.get('properties', {}).get('forecast')

        if forecast_url:
            forecast_response = requests.get(forecast_url)

            if forecast_response.status_code == 200:
                forecast_data = forecast_response.json()
                periods = forecast_data.get('properties', {}).get('periods', [])

                if periods:
                    return periods[0].get('detailedForecast', 'Weather forecast not available')
                else:
                    return 'Weather forecast not available'
            else:
                return f"Failed to retrieve forecast data. Status code: {forecast_response.status_code}"
        else:
            return 'Forecast URL not available in the response'
    else:
        return f"Failed to retrieve weather data. Status code: {response.status_code}"

# %% [markdown]
# The weather API requres lat, lon information, but we only have the location name...
#
# Let's use the OpenStreetMap API to get the lat, lon information from location name.

# %% [markdown]
# # OpenStreeetMap Geocoding API

# %%
# location name to lat lon

# Option 1: just string manipulation
base_url = "https://nominatim.openstreetmap.org/search.php"
query_params_str = "?q=Wallingford%2C+Seattle&format=jsonv2"
ful_url = base_url + query_params_str

# Option 2: use dictionary to represent query params
#           use requests.get(url, params=query_params) to attach the query param dict
query_params = {
    "q": "Wallingford, Seattle",
    "format": "jsonv2"
}

res = requests.get(base_url, params=query_params)
res.json()
# Out:
# [{'place_id': 312844859,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 150973716,
#   'lat': '47.6594631',
#   'lon': '-122.3343417',
#   'category': 'place',
#   'type': 'suburb',
#   'place_rank': 19,
#   'importance': 0.3131791431958073,
#   'addresstype': 'suburb',
#   'name': 'Wallingford',
#   'display_name': 'Wallingford, Seattle, King County, Washington, 98015, United States',
#   'boundingbox': ['47.6394631', '47.6794631', '-122.3543417', '-122.3143417']}]

# %%
import requests
from bs4 import BeautifulSoup
from geopy.geocoders import Nominatim  # Add this line
import csv
from datetime import datetime



# Function to get location coordinates using Nominatim
def get_location_coordinates(location):
  try:
    geolocator = Nominatim(user_agent="event_scraper")
    location_info = geolocator.geocode(location)
    if location_info:
        return location_info.latitude, location_info.longitude
    return None, None
  except Exception as e:
        print(f"An error occurred while getting location coordinates: {e}")
        return None, None

# %% [markdown]
# Now we have the lat, lon information for a location, we can use the Weather.gov API to get the weather information.

# %%
# Store event details with location and weather in a CSV file
csv_file_path = 'events_with_location_and_weather.csv'
fields = ['Name', 'Date', 'Location', 'Type', 'Region', 'URL', 'Latitude', 'Longitude', 'Weather']
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fields)
    writer.writeheader()

    for event_details in all_event_details:
        latitude, longitude = get_location_coordinates(event_details['Location'])

        weather = get_weather(latitude, longitude)
        print(weather)



        if latitude is not None and longitude is not None:


            writer.writerow({
                'Name': event_details['Name'],
                'Date': event_details['Date'],
                'Location': event_details['Location'],
                'Type': event_details['Type'],
                'Region': event_details['Region'],
                'Weather': weather,
                'Latitude': latitude,
                'Longitude': longitude,

            })
        else:
            print(f"Unable to get location coordinates for {event_details['Location']}")

print(f"Event details with location and weather stored in {csv_file_path}")
# Out:
# Mostly sunny, with a high near 52. East wind around 3 mph.
# Sunny. High near 65, with temperatures falling to around 63 in the afternoon. South southwest wind around 5 mph.
# Failed to retrieve weather data. Status code: 404
# Mostly cloudy, with a high near 53. South southwest wind around 3 mph.
# Isolated showers and thunderstorms before 5pm. Sunny, with a high near 64. Northwest wind around 8 mph. Chance of precipitation is 20%.
# Failed to retrieve weather data. Status code: 404
# Unable to get location coordinates for The Neptune Theatre
# Mostly cloudy, with a high near 53. South southwest wind around 3 mph.
# Mostly cloudy. High near 53, with temperatures falling to around 51 in the afternoon. Southwest wind around 5 mph.
# Mostly cloudy. High near 53, with temperatures falling to around 51 in the afternoon. South wind around 5 mph.
# Rain showers. Cloudy, with a high near 48. Southeast wind around 9 mph. Chance of precipitation is 80%. New rainfall amounts between a tenth and quarter of an inch possible.
# Mostly cloudy. High near 53, with temperatures falling to around 51 in the afternoon. Southwest wind around 5 mph.
# Mostly cloudy. High near 53, with temperatures falling to around 51 in the afternoon. South wind around 5 mph.
# Mostly cloudy, with a high near 53. South southwest wind around 3 mph.
# Failed to retrieve weather data. Status code: 404
# Sunny, with a high near 66. North northeast wind 10 to 14 mph, with gusts as high as 21 mph.
# Isolated showers and thunderstorms before 5pm. Sunny, with a high near 64. Northwest wind around 8 mph. Chance of precipitation is 20%.
# Mostly cloudy, with a high near 53. South southwest wind around 3 mph.
# Mostly cloudy. High near 53, with temperatures falling to around 51 in the afternoon. Southwest wind around 5 mph.
